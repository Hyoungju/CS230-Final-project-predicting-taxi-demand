# %%
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, Normalizer
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %matplotlib inline
# plt.style.use("ggplot")
sns.set_style("darkgrid")
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
data = pd.read_csv("final_1minutes.csv")
data.drop(['Month'], axis =1, inplace= True)
#data.set_index("time", inplace= True)
num_pickups = data.total
num_green_pickups = data.green
num_yellow_pickups = data.yellow
data.drop(['Unnamed: 0',  'green', 'yellow', 'total'], axis =1, inplace = True)

# %%
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    
    agg = pd.concat(cols, axis = 1)
    agg.columns = names
    
    if dropnan:
        agg.dropna(inplace = True)
        
    return agg

# %%
#normalize data & make LSTM model structure
features_and_target = pd.concat([data, num_pickups], axis = 1)
values = features_and_target.values

values = values.astype('float32')

scaler = MinMaxScaler(feature_range = (0, 1))
scaled = scaler.fit_transform(values)

n_hours = 47

reframed = series_to_supervised(scaled, n_hours, 1)

n_features = features_and_target.shape[1]

# %%
# exlcude significantly deviated data
total_values = reframed.values
n_p = np.argmin(total_values[365*24*3*60:, -1])
n_p = n_p + 365*24*3*60

a = total_values[: n_p, :]
b = total_values[n_p + n_hours + 60 + 1 : , :]
values = np.concatenate((a, b), axis=0)

# result variable
result = np.zeros((5, 7))

# %%
for i in range (7):
    values = total_values[total_values[:, -8] == total_values[120 + 24*i, 5]]
    n_train_hours = 225257
    train = values[:n_train_hours, :]
    test = values[n_train_hours:, :]
    # split into input and outputs
    n_obs = n_hours * n_features
    train_X, train_y = train[:, :n_obs], train[:, -1]
    test_X, test_y = test[:, :n_obs], test[:, -1]
    # reshape input to be 3D [samples, timesteps, features]
    train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
    test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))

    # design network
    model = Sequential()
    model.add(LSTM(24, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(1))
    model.compile(loss='mae', optimizer='adam')

    # fit network
    history = model.fit(train_X, train_y, epochs=100, batch_size=100,
                    validation_data=(test_X, test_y), verbose=2, shuffle=False)
    
    history_loss = pd.DataFrame()
    history_loss['train'] = history.history['loss']
    history_loss['test'] = history.history['val_loss']
    history_loss.plot(figsize=(5,5), fontsize=8,
                title='LSTM Model Loss');
    
    # make a prediction 
    yhat = model.predict(test_X)
    # reshape back to 2d
    test_X = test_X.reshape((test_X.shape[0], -1))

    # invert scaling for forecast# invert 
    inv_yhat = np.concatenate((test[:, 235:239], yhat), axis=1)
    inv_yhat = scaler.inverse_transform(inv_yhat)
    inv_yhat = inv_yhat[:,-1]

    # invert scaling for actual
    test_y = test_y.reshape((len(test_y), 1))
    inv_y = np.concatenate((test[:, 235:239], test_y), axis=1)
    inv_y = scaler.inverse_transform(inv_y)
    inv_y = inv_y[:,-1]
    inv_yhat_gte_zero = inv_yhat.copy()
    inv_yhat_gte_zero[inv_yhat_gte_zero < 0] = 0

    # calculate r2
    result[0, i] = r2_score(inv_y, inv_yhat)

    # calculate mean absolute error
    result[1, i] = mean_absolute_error(inv_y, inv_yhat)

    # calculate rmse
    rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))
    result[2, i]= rmse

    # calculate mean absolute error percentage
    maep = np.mean(np.abs((inv_y - inv_yhat)/inv_y))*100
    result[3, i] = maep
    
    #train bias
    yhat_t = model.predict(train_X)
    # reshape back to 2d
    train_X = train_X.reshape((train_X.shape[0], -1))

    # invert scaling for forecast# invert 
    inv_yhat_t = np.concatenate((train[:, 235:239], yhat_t), axis=1)
    inv_yhat_t = scaler.inverse_transform(inv_yhat_t)
    inv_yhat_t = inv_yhat_t[:,-1]

    # invert scaling for actual
    train_y = train_y.reshape((len(train_y), 1))
    inv_y_t = np.concatenate((train[:, 235:239], train_y), axis=1)
    inv_y_t = scaler.inverse_transform(inv_y_t)
    inv_y_t = inv_y_t[:,-1]
    inv_yhat_gte_zero = inv_yhat_t.copy()
    inv_yhat_gte_zero[inv_yhat_gte_zero < 0] = 0

    index = (np.abs((inv_y_t - inv_yhat_t)/inv_y_t) < 1)
    # calculate mean absolute error percentage
    maep = np.mean(np.abs((inv_y_t[index] - inv_yhat_t[index])/inv_y_t[index]))*100
    
    result[4, i] = maep
# Out:
# Train on 225257 samples, validate on 55543 samples
# Epoch 1/100
#  - 91s - loss: 0.0247 - val_loss: 0.0146
# Epoch 2/100
#  - 90s - loss: 0.0167 - val_loss: 0.0154
# Epoch 3/100
#  - 91s - loss: 0.0163 - val_loss: 0.0175
# Epoch 4/100
#  - 90s - loss: 0.0157 - val_loss: 0.0144
# Epoch 5/100
#  - 91s - loss: 0.0155 - val_loss: 0.0166
# Epoch 6/100
#  - 90s - loss: 0.0158 - val_loss: 0.0143
# Epoch 7/100
#  - 91s - loss: 0.0149 - val_loss: 0.0130
# Epoch 8/100
#  - 91s - loss: 0.0149 - val_loss: 0.0181
# Epoch 9/100
#  - 90s - loss: 0.0148 - val_loss: 0.0140
# Epoch 10/100
#  - 91s - loss: 0.0145 - val_loss: 0.0125
# Epoch 11/100
#  - 90s - loss: 0.0144 - val_loss: 0.0156
# Epoch 12/100
#  - 91s - loss: 0.0148 - val_loss: 0.0153
# Epoch 13/100
#  - 90s - loss: 0.0145 - val_loss: 0.0156
# Epoch 14/100
#  - 91s - loss: 0.0144 - val_loss: 0.0130
# Epoch 15/100
#  - 90s - loss: 0.0143 - val_loss: 0.0138
# Epoch 16/100
#  - 90s - loss: 0.0144 - val_loss: 0.0161
# Epoch 17/100
#  - 90s - loss: 0.0143 - val_loss: 0.0137
# Epoch 18/100
#  - 91s - loss: 0.0144 - val_loss: 0.0140
# Epoch 19/100
#  - 90s - loss: 0.0144 - val_loss: 0.0173
# Epoch 20/100
#  - 91s - loss: 0.0143 - val_loss: 0.0168
# Epoch 21/100
#  - 81s - loss: 0.0144 - val_loss: 0.0152
# Epoch 22/100
#  - 80s - loss: 0.0143 - val_loss: 0.0215
# Epoch 23/100
#  - 79s - loss: 0.0143 - val_loss: 0.0168
# Epoch 24/100
#  - 83s - loss: 0.0143 - val_loss: 0.0228
# Epoch 25/100
#  - 80s - loss: 0.0143 - val_loss: 0.0301
# Epoch 26/100
#  - 79s - loss: 0.0143 - val_loss: 0.0169
# Epoch 27/100
#  - 80s - loss: 0.0142 - val_loss: 0.0162
# Epoch 28/100
#  - 79s - loss: 0.0144 - val_loss: 0.0128
# Epoch 29/100
#  - 82s - loss: 0.0142 - val_loss: 0.0176
# Epoch 30/100
#  - 81s - loss: 0.0143 - val_loss: 0.0229
# Epoch 31/100
#  - 82s - loss: 0.0142 - val_loss: 0.0164
# Epoch 32/100
#  - 83s - loss: 0.0142 - val_loss: 0.0248
# Epoch 33/100
#  - 83s - loss: 0.0143 - val_loss: 0.0246
# Epoch 34/100
#  - 86s - loss: 0.0142 - val_loss: 0.0209
# Epoch 35/100
#  - 84s - loss: 0.0142 - val_loss: 0.0229
# Epoch 36/100
#  - 82s - loss: 0.0142 - val_loss: 0.0228
# Epoch 37/100
#  - 82s - loss: 0.0143 - val_loss: 0.0126
# Epoch 38/100
#  - 90s - loss: 0.0141 - val_loss: 0.0235
# Epoch 39/100
#  - 88s - loss: 0.0142 - val_loss: 0.0235
# Epoch 40/100
#  - 89s - loss: 0.0142 - val_loss: 0.0216
# Epoch 41/100
#  - 90s - loss: 0.0142 - val_loss: 0.0225
# Epoch 42/100
#  - 89s - loss: 0.0142 - val_loss: 0.0163
# Epoch 43/100
#  - 90s - loss: 0.0141 - val_loss: 0.0187
# Epoch 44/100
#  - 90s - loss: 0.0142 - val_loss: 0.0130
# Epoch 45/100
#  - 89s - loss: 0.0141 - val_loss: 0.0209
# Epoch 46/100
#  - 90s - loss: 0.0141 - val_loss: 0.0165
# Epoch 47/100
#  - 90s - loss: 0.0141 - val_loss: 0.0168
# Epoch 48/100
#  - 89s - loss: 0.0141 - val_loss: 0.0143
# Epoch 49/100
#  - 90s - loss: 0.0140 - val_loss: 0.0154
# Epoch 50/100
#  - 89s - loss: 0.0141 - val_loss: 0.0172
# Epoch 51/100
#  - 90s - loss: 0.0141 - val_loss: 0.0160
# Epoch 52/100
#  - 88s - loss: 0.0141 - val_loss: 0.0127
# Epoch 53/100
#  - 90s - loss: 0.0140 - val_loss: 0.0150
# Epoch 54/100
#  - 89s - loss: 0.0141 - val_loss: 0.0165
# Epoch 55/100
#  - 90s - loss: 0.0141 - val_loss: 0.0125
# Epoch 56/100
#  - 90s - loss: 0.0140 - val_loss: 0.0122
# Epoch 57/100
#  - 93s - loss: 0.0140 - val_loss: 0.0134
# Epoch 58/100
#  - 90s - loss: 0.0141 - val_loss: 0.0124
# Epoch 59/100
#  - 90s - loss: 0.0140 - val_loss: 0.0131
# Epoch 60/100
#  - 91s - loss: 0.0140 - val_loss: 0.0144
# Epoch 61/100
#  - 92s - loss: 0.0140 - val_loss: 0.0143
# Epoch 62/100
#  - 94s - loss: 0.0140 - val_loss: 0.0139
# Epoch 63/100
#  - 90s - loss: 0.0140 - val_loss: 0.0137
# Epoch 64/100
#  - 91s - loss: 0.0140 - val_loss: 0.0144
# Epoch 65/100
#  - 91s - loss: 0.0140 - val_loss: 0.0122
# Epoch 66/100
#  - 91s - loss: 0.0140 - val_loss: 0.0151
# Epoch 67/100
#  - 90s - loss: 0.0140 - val_loss: 0.0128
# Epoch 68/100
#  - 90s - loss: 0.0140 - val_loss: 0.0137
# Epoch 69/100
#  - 90s - loss: 0.0140 - val_loss: 0.0137
# Epoch 70/100
#  - 90s - loss: 0.0140 - val_loss: 0.0126
# Epoch 71/100
#  - 90s - loss: 0.0140 - val_loss: 0.0126
# Epoch 72/100
#  - 90s - loss: 0.0140 - val_loss: 0.0124
# Epoch 73/100
#  - 90s - loss: 0.0139 - val_loss: 0.0132
# Epoch 74/100
#  - 91s - loss: 0.0140 - val_loss: 0.0122
# Epoch 75/100
#  - 90s - loss: 0.0139 - val_loss: 0.0126
# Epoch 76/100
#  - 91s - loss: 0.0140 - val_loss: 0.0126
# Epoch 77/100
#  - 90s - loss: 0.0139 - val_loss: 0.0125
# Epoch 78/100
#  - 91s - loss: 0.0140 - val_loss: 0.0123
# Epoch 79/100
#  - 90s - loss: 0.0139 - val_loss: 0.0122
# Epoch 80/100
#  - 91s - loss: 0.0139 - val_loss: 0.0127
# Epoch 81/100
#  - 90s - loss: 0.0139 - val_loss: 0.0132
# Epoch 82/100
#  - 91s - loss: 0.0140 - val_loss: 0.0132
# Epoch 83/100
#  - 90s - loss: 0.0139 - val_loss: 0.0124
# Epoch 84/100
#  - 91s - loss: 0.0139 - val_loss: 0.0125
# Epoch 85/100
#  - 89s - loss: 0.0139 - val_loss: 0.0130
# Epoch 86/100
#  - 91s - loss: 0.0139 - val_loss: 0.0122
# Epoch 87/100
#  - 90s - loss: 0.0139 - val_loss: 0.0124
# Epoch 88/100
#  - 91s - loss: 0.0139 - val_loss: 0.0123
# Epoch 89/100
#  - 90s - loss: 0.0139 - val_loss: 0.0126
# Epoch 90/100
#  - 90s - loss: 0.0139 - val_loss: 0.0125
# Epoch 91/100
#  - 90s - loss: 0.0139 - val_loss: 0.0123
# Epoch 92/100
#  - 90s - loss: 0.0139 - val_loss: 0.0127
# Epoch 93/100
#  - 90s - loss: 0.0139 - val_loss: 0.0124
# Epoch 94/100
#  - 91s - loss: 0.0139 - val_loss: 0.0123
# Epoch 95/100
#  - 90s - loss: 0.0139 - val_loss: 0.0123
# Epoch 96/100
#  - 90s - loss: 0.0139 - val_loss: 0.0123
# Epoch 97/100
#  - 91s - loss: 0.0139 - val_loss: 0.0122
# Epoch 98/100
#  - 91s - loss: 0.0139 - val_loss: 0.0128
# Epoch 99/100
#  - 90s - loss: 0.0138 - val_loss: 0.0123
# Epoch 100/100
#  - 90s - loss: 0.0139 - val_loss: 0.0122
# Train on 225257 samples, validate on 55543 samples
# Epoch 1/100
#  - 91s - loss: 0.0294 - val_loss: 0.0322
# Epoch 2/100
#  - 90s - loss: 0.0167 - val_loss: 0.0138
# Epoch 3/100
#  - 91s - loss: 0.0163 - val_loss: 0.0149
# Epoch 4/100
#  - 91s - loss: 0.0159 - val_loss: 0.0180
# Epoch 5/100
#  - 91s - loss: 0.0152 - val_loss: 0.0151
# Epoch 6/100
#  - 91s - loss: 0.0151 - val_loss: 0.0189
# Epoch 7/100
#  - 91s - loss: 0.0148 - val_loss: 0.0137
# Epoch 8/100
#  - 91s - loss: 0.0148 - val_loss: 0.0163
# Epoch 9/100
#  - 91s - loss: 0.0147 - val_loss: 0.0132
# Epoch 10/100
#  - 90s - loss: 0.0146 - val_loss: 0.0136
# Epoch 11/100
#  - 91s - loss: 0.0145 - val_loss: 0.0153
# Epoch 12/100
#  - 90s - loss: 0.0145 - val_loss: 0.0138
# Epoch 13/100
#  - 91s - loss: 0.0144 - val_loss: 0.0165
# Epoch 14/100
#  - 90s - loss: 0.0145 - val_loss: 0.0159
# Epoch 15/100
#  - 91s - loss: 0.0144 - val_loss: 0.0175
# Epoch 16/100
#  - 90s - loss: 0.0144 - val_loss: 0.0165
# Epoch 17/100
#  - 91s - loss: 0.0144 - val_loss: 0.0176
# Epoch 18/100
#  - 90s - loss: 0.0143 - val_loss: 0.0170
# Epoch 19/100
#  - 91s - loss: 0.0144 - val_loss: 0.0303
# Epoch 20/100
#  - 89s - loss: 0.0144 - val_loss: 0.0218
# Epoch 21/100
#  - 91s - loss: 0.0144 - val_loss: 0.0194
# Epoch 22/100
#  - 90s - loss: 0.0143 - val_loss: 0.0209
# Epoch 23/100
#  - 91s - loss: 0.0143 - val_loss: 0.0223
# Epoch 24/100
#  - 90s - loss: 0.0143 - val_loss: 0.0283
# Epoch 25/100
#  - 90s - loss: 0.0143 - val_loss: 0.0144
# Epoch 26/100
#  - 90s - loss: 0.0143 - val_loss: 0.0132
# Epoch 27/100
#  - 91s - loss: 0.0142 - val_loss: 0.0127
# Epoch 28/100
#  - 90s - loss: 0.0143 - val_loss: 0.0188
# Epoch 29/100
#  - 89s - loss: 0.0142 - val_loss: 0.0163
# Epoch 30/100
#  - 90s - loss: 0.0143 - val_loss: 0.0170
# Epoch 31/100
#  - 91s - loss: 0.0142 - val_loss: 0.0186
# Epoch 32/100
#  - 90s - loss: 0.0142 - val_loss: 0.0196
# Epoch 33/100
#  - 86s - loss: 0.0142 - val_loss: 0.0175
# Epoch 34/100
#  - 80s - loss: 0.0142 - val_loss: 0.0258
# Epoch 35/100
#  - 79s - loss: 0.0143 - val_loss: 0.0201
# Epoch 36/100
#  - 80s - loss: 0.0143 - val_loss: 0.0136
# Epoch 37/100
#  - 80s - loss: 0.0142 - val_loss: 0.0236
# Epoch 38/100
#  - 80s - loss: 0.0142 - val_loss: 0.0135
# Epoch 39/100
#  - 79s - loss: 0.0141 - val_loss: 0.0223
# Epoch 40/100
#  - 79s - loss: 0.0142 - val_loss: 0.0170
# Epoch 41/100
#  - 81s - loss: 0.0141 - val_loss: 0.0223
# Epoch 42/100
#  - 82s - loss: 0.0142 - val_loss: 0.0129
# Epoch 43/100
#  - 83s - loss: 0.0141 - val_loss: 0.0164
# Epoch 44/100
#  - 84s - loss: 0.0142 - val_loss: 0.0126
# Epoch 45/100
#  - 84s - loss: 0.0141 - val_loss: 0.0126
# Epoch 46/100
#  - 86s - loss: 0.0141 - val_loss: 0.0159
# Epoch 47/100
#  - 85s - loss: 0.0141 - val_loss: 0.0186
# Epoch 48/100
#  - 82s - loss: 0.0141 - val_loss: 0.0160
# Epoch 49/100
#  - 84s - loss: 0.0141 - val_loss: 0.0154
# Epoch 50/100
#  - 90s - loss: 0.0141 - val_loss: 0.0134
# Epoch 51/100
#  - 88s - loss: 0.0140 - val_loss: 0.0145
# Epoch 52/100
#  - 90s - loss: 0.0140 - val_loss: 0.0158
# Epoch 53/100
#  - 90s - loss: 0.0141 - val_loss: 0.0186
# Epoch 54/100
#  - 90s - loss: 0.0141 - val_loss: 0.0142
# Epoch 55/100
#  - 91s - loss: 0.0140 - val_loss: 0.0170
# Epoch 56/100
#  - 90s - loss: 0.0141 - val_loss: 0.0152
# Epoch 57/100
#  - 91s - loss: 0.0141 - val_loss: 0.0188
# Epoch 58/100
#  - 91s - loss: 0.0140 - val_loss: 0.0139
# Epoch 59/100
#  - 90s - loss: 0.0140 - val_loss: 0.0169
# Epoch 60/100
#  - 90s - loss: 0.0140 - val_loss: 0.0156
# Epoch 61/100
#  - 91s - loss: 0.0140 - val_loss: 0.0135
# Epoch 62/100
#  - 90s - loss: 0.0140 - val_loss: 0.0159
# Epoch 63/100
#  - 90s - loss: 0.0141 - val_loss: 0.0132
# Epoch 64/100
#  - 91s - loss: 0.0140 - val_loss: 0.0127
# Epoch 65/100
#  - 91s - loss: 0.0141 - val_loss: 0.0142
# Epoch 66/100
#  - 93s - loss: 0.0141 - val_loss: 0.0130
# Epoch 67/100
#  - 93s - loss: 0.0140 - val_loss: 0.0145
# Epoch 68/100
#  - 90s - loss: 0.0141 - val_loss: 0.0139
# Epoch 69/100
#  - 91s - loss: 0.0141 - val_loss: 0.0132
# Epoch 70/100
#  - 90s - loss: 0.0140 - val_loss: 0.0125
# Epoch 71/100
#  - 92s - loss: 0.0140 - val_loss: 0.0125
# Epoch 72/100
#  - 89s - loss: 0.0140 - val_loss: 0.0127
# Epoch 73/100
#  - 91s - loss: 0.0140 - val_loss: 0.0135
# Epoch 74/100
#  - 90s - loss: 0.0140 - val_loss: 0.0124
# Epoch 75/100
#  - 91s - loss: 0.0140 - val_loss: 0.0130
# Epoch 76/100
#  - 90s - loss: 0.0140 - val_loss: 0.0127
# Epoch 77/100
#  - 92s - loss: 0.0140 - val_loss: 0.0126
# Epoch 78/100
#  - 91s - loss: 0.0140 - val_loss: 0.0122
# Epoch 79/100
#  - 91s - loss: 0.0140 - val_loss: 0.0125
# Epoch 80/100
#  - 91s - loss: 0.0140 - val_loss: 0.0122
# Epoch 81/100
#  - 91s - loss: 0.0139 - val_loss: 0.0128
# Epoch 82/100
#  - 90s - loss: 0.0139 - val_loss: 0.0127
# Epoch 83/100
#  - 91s - loss: 0.0140 - val_loss: 0.0123
# Epoch 84/100
#  - 90s - loss: 0.0139 - val_loss: 0.0123
# Epoch 85/100
#  - 91s - loss: 0.0140 - val_loss: 0.0123
# Epoch 86/100
#  - 91s - loss: 0.0139 - val_loss: 0.0122
# Epoch 87/100
#  - 91s - loss: 0.0139 - val_loss: 0.0127
# Epoch 88/100
#  - 91s - loss: 0.0139 - val_loss: 0.0122
# Epoch 89/100
#  - 90s - loss: 0.0139 - val_loss: 0.0122
# Epoch 90/100
#  - 91s - loss: 0.0139 - val_loss: 0.0122
# Epoch 91/100
#  - 90s - loss: 0.0139 - val_loss: 0.0122
# Epoch 92/100
#  - 92s - loss: 0.0139 - val_loss: 0.0122
# Epoch 93/100
#  - 91s - loss: 0.0139 - val_loss: 0.0125
# Epoch 94/100
#  - 92s - loss: 0.0139 - val_loss: 0.0124
# Epoch 95/100
#  - 90s - loss: 0.0139 - val_loss: 0.0122
# Epoch 96/100
#  - 92s - loss: 0.0139 - val_loss: 0.0121
# Epoch 97/100
#  - 90s - loss: 0.0139 - val_loss: 0.0122
# Epoch 98/100
#  - 91s - loss: 0.0139 - val_loss: 0.0122
# Epoch 99/100
#  - 91s - loss: 0.0140 - val_loss: 0.0122
# Epoch 100/100
#  - 91s - loss: 0.0139 - val_loss: 0.0122
# Train on 225257 samples, validate on 55543 samples
# Epoch 1/100
#  - 92s - loss: 0.0216 - val_loss: 0.0140
# Epoch 2/100
#  - 92s - loss: 0.0160 - val_loss: 0.0180
# Epoch 3/100
#  - 90s - loss: 0.0154 - val_loss: 0.0211
# Epoch 4/100
#  - 91s - loss: 0.0152 - val_loss: 0.0133
# Epoch 5/100
#  - 90s - loss: 0.0150 - val_loss: 0.0189
# Epoch 6/100
#  - 92s - loss: 0.0151 - val_loss: 0.0159
# Epoch 7/100
#  - 90s - loss: 0.0146 - val_loss: 0.0204
# Epoch 8/100
#  - 91s - loss: 0.0147 - val_loss: 0.0157
# Epoch 9/100
#  - 91s - loss: 0.0145 - val_loss: 0.0128
# Epoch 10/100
#  - 93s - loss: 0.0145 - val_loss: 0.0133
# Epoch 11/100
#  - 90s - loss: 0.0146 - val_loss: 0.0168
# Epoch 12/100
#  - 91s - loss: 0.0145 - val_loss: 0.0134
# Epoch 13/100
#  - 90s - loss: 0.0144 - val_loss: 0.0129
# Epoch 14/100
#  - 91s - loss: 0.0143 - val_loss: 0.0130
# Epoch 15/100
#  - 91s - loss: 0.0144 - val_loss: 0.0153
# Epoch 16/100
#  - 91s - loss: 0.0144 - val_loss: 0.0128
# Epoch 17/100
#  - 90s - loss: 0.0143 - val_loss: 0.0165
# Epoch 18/100
#  - 91s - loss: 0.0144 - val_loss: 0.0171
# Epoch 19/100
#  - 90s - loss: 0.0143 - val_loss: 0.0139
# Epoch 20/100
#  - 91s - loss: 0.0143 - val_loss: 0.0163
# Epoch 21/100
#  - 90s - loss: 0.0143 - val_loss: 0.0157
# Epoch 22/100
#  - 91s - loss: 0.0142 - val_loss: 0.0171
# Epoch 23/100
#  - 91s - loss: 0.0143 - val_loss: 0.0162
# Epoch 24/100
#  - 90s - loss: 0.0143 - val_loss: 0.0148
# Epoch 25/100
#  - 91s - loss: 0.0142 - val_loss: 0.0197
# Epoch 26/100
#  - 91s - loss: 0.0142 - val_loss: 0.0194
# Epoch 27/100
#  - 90s - loss: 0.0143 - val_loss: 0.0187
# Epoch 28/100
#  - 91s - loss: 0.0143 - val_loss: 0.0180
# Epoch 29/100
#  - 90s - loss: 0.0142 - val_loss: 0.0243
# Epoch 30/100
#  - 91s - loss: 0.0143 - val_loss: 0.0137
# Epoch 31/100
#  - 90s - loss: 0.0142 - val_loss: 0.0157
# Epoch 32/100
#  - 91s - loss: 0.0142 - val_loss: 0.0209
# Epoch 33/100
#  - 90s - loss: 0.0142 - val_loss: 0.0153
# Epoch 34/100
#  - 91s - loss: 0.0142 - val_loss: 0.0138
# Epoch 35/100
#  - 90s - loss: 0.0142 - val_loss: 0.0173
# Epoch 36/100
#  - 91s - loss: 0.0141 - val_loss: 0.0179
# Epoch 37/100
#  - 91s - loss: 0.0143 - val_loss: 0.0187
# Epoch 38/100
#  - 90s - loss: 0.0142 - val_loss: 0.0140
# Epoch 39/100
#  - 91s - loss: 0.0141 - val_loss: 0.0205
# Epoch 40/100
#  - 90s - loss: 0.0141 - val_loss: 0.0178
# Epoch 41/100
#  - 91s - loss: 0.0142 - val_loss: 0.0171
# Epoch 42/100
#  - 85s - loss: 0.0141 - val_loss: 0.0187
# Epoch 43/100
#  - 80s - loss: 0.0141 - val_loss: 0.0191
# Epoch 44/100
#  - 80s - loss: 0.0142 - val_loss: 0.0165
# Epoch 45/100
#  - 79s - loss: 0.0141 - val_loss: 0.0216
# Epoch 46/100
#  - 81s - loss: 0.0142 - val_loss: 0.0174
# Epoch 47/100
#  - 79s - loss: 0.0141 - val_loss: 0.0189
# Epoch 48/100
#  - 80s - loss: 0.0141 - val_loss: 0.0160
# Epoch 49/100
#  - 80s - loss: 0.0142 - val_loss: 0.0160
# Epoch 50/100
#  - 81s - loss: 0.0141 - val_loss: 0.0153
# Epoch 51/100
#  - 81s - loss: 0.0141 - val_loss: 0.0167
# Epoch 52/100
#  - 83s - loss: 0.0141 - val_loss: 0.0145
# Epoch 53/100
#  - 83s - loss: 0.0141 - val_loss: 0.0146
# Epoch 54/100
#  - 85s - loss: 0.0141 - val_loss: 0.0141
# Epoch 55/100
#  - 86s - loss: 0.0141 - val_loss: 0.0143
# Epoch 56/100
#  - 83s - loss: 0.0141 - val_loss: 0.0149
# Epoch 57/100
#  - 83s - loss: 0.0141 - val_loss: 0.0143
# Epoch 58/100
#  - 85s - loss: 0.0141 - val_loss: 0.0151
# Epoch 59/100
#  - 91s - loss: 0.0140 - val_loss: 0.0168
# Epoch 60/100
#  - 88s - loss: 0.0141 - val_loss: 0.0153
# Epoch 61/100
#  - 91s - loss: 0.0140 - val_loss: 0.0148
# Epoch 62/100
#  - 90s - loss: 0.0140 - val_loss: 0.0150
# Epoch 63/100
#  - 91s - loss: 0.0140 - val_loss: 0.0155
# Epoch 64/100
#  - 88s - loss: 0.0140 - val_loss: 0.0144
# Epoch 65/100
#  - 91s - loss: 0.0140 - val_loss: 0.0151
# Epoch 66/100
#  - 90s - loss: 0.0140 - val_loss: 0.0146
# Epoch 67/100
#  - 90s - loss: 0.0140 - val_loss: 0.0151
# Epoch 68/100
#  - 90s - loss: 0.0140 - val_loss: 0.0132
# Epoch 69/100
#  - 91s - loss: 0.0140 - val_loss: 0.0149
# Epoch 70/100
#  - 90s - loss: 0.0140 - val_loss: 0.0138
# Epoch 71/100
#  - 91s - loss: 0.0140 - val_loss: 0.0132
# Epoch 72/100
#  - 91s - loss: 0.0140 - val_loss: 0.0130
# Epoch 73/100
#  - 90s - loss: 0.0140 - val_loss: 0.0132
# Epoch 74/100
#  - 91s - loss: 0.0140 - val_loss: 0.0139
# Epoch 75/100
#  - 91s - loss: 0.0140 - val_loss: 0.0138
# Epoch 76/100
#  - 91s - loss: 0.0140 - val_loss: 0.0135
# Epoch 77/100
#  - 92s - loss: 0.0139 - val_loss: 0.0141
# Epoch 78/100
#  - 91s - loss: 0.0140 - val_loss: 0.0130
# Epoch 79/100
#  - 92s - loss: 0.0139 - val_loss: 0.0139
# Epoch 80/100
#  - 91s - loss: 0.0139 - val_loss: 0.0137
# Epoch 81/100
#  - 92s - loss: 0.0140 - val_loss: 0.0122
# Epoch 82/100
#  - 91s - loss: 0.0139 - val_loss: 0.0135
# Epoch 83/100
#  - 91s - loss: 0.0139 - val_loss: 0.0134
# Epoch 84/100
#  - 91s - loss: 0.0140 - val_loss: 0.0128
# Epoch 85/100
#  - 92s - loss: 0.0139 - val_loss: 0.0141
# Epoch 86/100
#  - 91s - loss: 0.0139 - val_loss: 0.0143
# Epoch 87/100
#  - 91s - loss: 0.0139 - val_loss: 0.0128
# Epoch 88/100
#  - 91s - loss: 0.0139 - val_loss: 0.0130
# Epoch 89/100
#  - 90s - loss: 0.0139 - val_loss: 0.0134
# Epoch 90/100
#  - 91s - loss: 0.0139 - val_loss: 0.0127
# Epoch 91/100
#  - 91s - loss: 0.0140 - val_loss: 0.0123
# Epoch 92/100
#  - 91s - loss: 0.0139 - val_loss: 0.0131
# Epoch 93/100
#  - 91s - loss: 0.0139 - val_loss: 0.0127
# Epoch 94/100
#  - 92s - loss: 0.0140 - val_loss: 0.0122
# Epoch 95/100
#  - 91s - loss: 0.0139 - val_loss: 0.0128
# Epoch 96/100
#  - 91s - loss: 0.0139 - val_loss: 0.0131
# Epoch 97/100
#  - 92s - loss: 0.0139 - val_loss: 0.0127
# Epoch 98/100
#  - 91s - loss: 0.0140 - val_loss: 0.0123
# Epoch 99/100
#  - 91s - loss: 0.0139 - val_loss: 0.0122
# Epoch 100/100
#  - 93s - loss: 0.0139 - val_loss: 0.0123
# Train on 225257 samples, validate on 55543 samples
# Epoch 1/100
#  - 92s - loss: 0.0227 - val_loss: 0.0141
# Epoch 2/100
#  - 91s - loss: 0.0162 - val_loss: 0.0185
# Epoch 3/100
#  - 91s - loss: 0.0153 - val_loss: 0.0144
# Epoch 4/100
#  - 91s - loss: 0.0155 - val_loss: 0.0135
# Epoch 5/100
#  - 91s - loss: 0.0151 - val_loss: 0.0145
# Epoch 6/100
#  - 92s - loss: 0.0149 - val_loss: 0.0153
# Epoch 7/100
#  - 91s - loss: 0.0148 - val_loss: 0.0151
# Epoch 8/100
#  - 92s - loss: 0.0146 - val_loss: 0.0127
# Epoch 9/100
#  - 91s - loss: 0.0146 - val_loss: 0.0126
# Epoch 10/100
#  - 92s - loss: 0.0145 - val_loss: 0.0128
# Epoch 11/100
#  - 91s - loss: 0.0146 - val_loss: 0.0148
# Epoch 12/100
#  - 92s - loss: 0.0144 - val_loss: 0.0157
# Epoch 13/100
#  - 91s - loss: 0.0145 - val_loss: 0.0129
# Epoch 14/100
#  - 92s - loss: 0.0144 - val_loss: 0.0203
# Epoch 15/100
#  - 90s - loss: 0.0143 - val_loss: 0.0130
# Epoch 16/100
#  - 92s - loss: 0.0143 - val_loss: 0.0138
# Epoch 17/100
#  - 90s - loss: 0.0143 - val_loss: 0.0147
# Epoch 18/100
#  - 91s - loss: 0.0143 - val_loss: 0.0125
# Epoch 19/100
#  - 91s - loss: 0.0142 - val_loss: 0.0135
# Epoch 20/100
#  - 92s - loss: 0.0144 - val_loss: 0.0143
# Epoch 21/100
#  - 91s - loss: 0.0142 - val_loss: 0.0176
# Epoch 22/100
#  - 91s - loss: 0.0144 - val_loss: 0.0139
# Epoch 23/100
#  - 91s - loss: 0.0142 - val_loss: 0.0144
# Epoch 24/100
#  - 91s - loss: 0.0142 - val_loss: 0.0221
# Epoch 25/100
#  - 91s - loss: 0.0143 - val_loss: 0.0152
# Epoch 26/100
#  - 91s - loss: 0.0142 - val_loss: 0.0153
# Epoch 27/100
#  - 90s - loss: 0.0143 - val_loss: 0.0152
# Epoch 28/100
#  - 90s - loss: 0.0142 - val_loss: 0.0171
# Epoch 29/100
#  - 91s - loss: 0.0143 - val_loss: 0.0199
# Epoch 30/100
#  - 91s - loss: 0.0143 - val_loss: 0.0209
# Epoch 31/100
#  - 91s - loss: 0.0142 - val_loss: 0.0239
# Epoch 32/100
#  - 92s - loss: 0.0143 - val_loss: 0.0257
# Epoch 33/100
#  - 91s - loss: 0.0142 - val_loss: 0.0138
# Epoch 34/100
#  - 91s - loss: 0.0142 - val_loss: 0.0133
# Epoch 35/100
#  - 88s - loss: 0.0142 - val_loss: 0.0144
# Epoch 36/100
#  - 91s - loss: 0.0141 - val_loss: 0.0151
# Epoch 37/100
#  - 89s - loss: 0.0142 - val_loss: 0.0179
# Epoch 38/100
#  - 92s - loss: 0.0142 - val_loss: 0.0237
# Epoch 39/100
#  - 88s - loss: 0.0142 - val_loss: 0.0212
# Epoch 40/100
#  - 92s - loss: 0.0142 - val_loss: 0.0243
# Epoch 41/100
#  - 91s - loss: 0.0143 - val_loss: 0.0191
# Epoch 42/100
#  - 96s - loss: 0.0142 - val_loss: 0.0222
# Epoch 43/100
#  - 90s - loss: 0.0142 - val_loss: 0.0191
# Epoch 44/100
#  - 91s - loss: 0.0142 - val_loss: 0.0199
# Epoch 45/100
#  - 89s - loss: 0.0142 - val_loss: 0.0170
# Epoch 46/100
#  - 89s - loss: 0.0142 - val_loss: 0.0187
# Epoch 47/100
#  - 91s - loss: 0.0142 - val_loss: 0.0189
# Epoch 48/100
#  - 88s - loss: 0.0142 - val_loss: 0.0157
# Epoch 49/100
#  - 90s - loss: 0.0141 - val_loss: 0.0204
# Epoch 50/100
#  - 89s - loss: 0.0142 - val_loss: 0.0133
# Epoch 51/100
#  - 91s - loss: 0.0141 - val_loss: 0.0172
# Epoch 52/100
#  - 88s - loss: 0.0141 - val_loss: 0.0181
# Epoch 53/100
#  - 90s - loss: 0.0141 - val_loss: 0.0191
# Epoch 54/100
#  - 89s - loss: 0.0141 - val_loss: 0.0139
# Epoch 55/100
#  - 90s - loss: 0.0141 - val_loss: 0.0164
# Epoch 56/100
#  - 91s - loss: 0.0141 - val_loss: 0.0125
# Epoch 57/100
#  - 81s - loss: 0.0140 - val_loss: 0.0168
# Epoch 58/100
#  - 81s - loss: 0.0141 - val_loss: 0.0168
# Epoch 59/100
#  - 79s - loss: 0.0141 - val_loss: 0.0139
# Epoch 60/100
#  - 80s - loss: 0.0140 - val_loss: 0.0164
# Epoch 61/100
#  - 80s - loss: 0.0141 - val_loss: 0.0140
# Epoch 62/100
#  - 80s - loss: 0.0140 - val_loss: 0.0146
# Epoch 63/100
#  - 80s - loss: 0.0140 - val_loss: 0.0126
# Epoch 64/100
#  - 80s - loss: 0.0140 - val_loss: 0.0158
# Epoch 65/100
#  - 81s - loss: 0.0141 - val_loss: 0.0163
# Epoch 66/100
#  - 81s - loss: 0.0141 - val_loss: 0.0152
# Epoch 67/100
#  - 83s - loss: 0.0141 - val_loss: 0.0139
# Epoch 68/100
#  - 83s - loss: 0.0140 - val_loss: 0.0138
# Epoch 69/100
#  - 84s - loss: 0.0141 - val_loss: 0.0122
# Epoch 70/100
#  - 86s - loss: 0.0140 - val_loss: 0.0132
# Epoch 71/100
#  - 87s - loss: 0.0140 - val_loss: 0.0139
# Epoch 72/100
#  - 84s - loss: 0.0140 - val_loss: 0.0148
# Epoch 73/100
#  - 82s - loss: 0.0140 - val_loss: 0.0138
# Epoch 74/100
#  - 87s - loss: 0.0140 - val_loss: 0.0138
# Epoch 75/100
#  - 91s - loss: 0.0140 - val_loss: 0.0129
# Epoch 76/100
#  - 87s - loss: 0.0140 - val_loss: 0.0135
# Epoch 77/100
#  - 91s - loss: 0.0140 - val_loss: 0.0133
# Epoch 78/100
#  - 91s - loss: 0.0140 - val_loss: 0.0125
# Epoch 79/100
#  - 91s - loss: 0.0140 - val_loss: 0.0123
# Epoch 80/100
#  - 90s - loss: 0.0140 - val_loss: 0.0133
# Epoch 81/100
#  - 91s - loss: 0.0140 - val_loss: 0.0132
# Epoch 82/100
#  - 90s - loss: 0.0140 - val_loss: 0.0123
# Epoch 83/100
#  - 91s - loss: 0.0140 - val_loss: 0.0122
# Epoch 84/100
#  - 89s - loss: 0.0140 - val_loss: 0.0132
# Epoch 85/100
#  - 91s - loss: 0.0140 - val_loss: 0.0133
# Epoch 86/100
#  - 90s - loss: 0.0140 - val_loss: 0.0123
# Epoch 87/100
#  - 92s - loss: 0.0139 - val_loss: 0.0123
# Epoch 88/100
#  - 91s - loss: 0.0139 - val_loss: 0.0129
# Epoch 89/100
#  - 91s - loss: 0.0139 - val_loss: 0.0123
# Epoch 90/100
#  - 90s - loss: 0.0139 - val_loss: 0.0135
# Epoch 91/100
#  - 91s - loss: 0.0139 - val_loss: 0.0124
# Epoch 92/100
#  - 90s - loss: 0.0139 - val_loss: 0.0122
# Epoch 93/100
#  - 91s - loss: 0.0139 - val_loss: 0.0131
# Epoch 94/100
#  - 90s - loss: 0.0139 - val_loss: 0.0123
# Epoch 95/100
#  - 91s - loss: 0.0139 - val_loss: 0.0132
# Epoch 96/100
#  - 91s - loss: 0.0139 - val_loss: 0.0123
# Epoch 97/100
#  - 90s - loss: 0.0139 - val_loss: 0.0130
# Epoch 98/100
#  - 88s - loss: 0.0139 - val_loss: 0.0123
# Epoch 99/100
#  - 88s - loss: 0.0139 - val_loss: 0.0123
# Epoch 100/100
#  - 87s - loss: 0.0139 - val_loss: 0.0122
# Train on 225257 samples, validate on 55543 samples
# Epoch 1/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f21099959d32> in <module>()
#      20     # fit network
#      21     history = model.fit(train_X, train_y, epochs=100, batch_size=100,
# ---> 22                     validation_data=(test_X, test_y), verbose=2, shuffle=False)
#      23
#      24     history_loss = pd.DataFrame()
#
# ~/anaconda3/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1000                               initial_epoch=initial_epoch,
#    1001                               steps_per_epoch=steps_per_epoch,
# -> 1002                               validation_steps=validation_steps)
#    1003
#    1004     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1234                         ins_batch[i] = ins_batch[i].toarray()
#    1235
# -> 1236                     outs = f(ins_batch)
#    1237                     if not isinstance(outs, list):
#    1238                         outs = [outs]
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
result
# Out:
# array([[ 0.97739982,  0.97731584,  0.97700463,  0.97707304,  0.        ,
#          0.        ,  0.        ],
#        [12.31046486, 12.33949184, 12.40036583, 12.33231163,  0.        ,
#          0.        ,  0.        ],
#        [16.10004617, 16.12993127, 16.24020137, 16.21602518,  0.        ,
#          0.        ,  0.        ],
#        [ 7.7351056 ,  7.62838051,  7.52845481,  7.43509382,  0.        ,
#          0.        ,  0.        ],
#        [ 6.77554458,  6.53565377,  6.57253638,  6.6437453 ,  0.        ,
#          0.        ,  0.        ]])

# %%
for i in range (4, 7):
    values = total_values[total_values[:, -8] == total_values[120 + 24*i, 5]]
    n_train_hours = 225257
    train = values[:n_train_hours, :]
    test = values[n_train_hours:, :]
    # split into input and outputs
    n_obs = n_hours * n_features
    train_X, train_y = train[:, :n_obs], train[:, -1]
    test_X, test_y = test[:, :n_obs], test[:, -1]
    # reshape input to be 3D [samples, timesteps, features]
    train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
    test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))

    # design network
    model = Sequential()
    model.add(LSTM(24, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(1))
    model.compile(loss='mae', optimizer='adam')

    # fit network
    history = model.fit(train_X, train_y, epochs=100, batch_size=100,
                    validation_data=(test_X, test_y), verbose=2, shuffle=False)
    
    history_loss = pd.DataFrame()
    history_loss['train'] = history.history['loss']
    history_loss['test'] = history.history['val_loss']
    history_loss.plot(figsize=(5,5), fontsize=8,
                title='LSTM Model Loss');
    
    # make a prediction 
    yhat = model.predict(test_X)
    # reshape back to 2d
    test_X = test_X.reshape((test_X.shape[0], -1))

    # invert scaling for forecast# invert 
    inv_yhat = np.concatenate((test[:, 235:239], yhat), axis=1)
    inv_yhat = scaler.inverse_transform(inv_yhat)
    inv_yhat = inv_yhat[:,-1]

    # invert scaling for actual
    test_y = test_y.reshape((len(test_y), 1))
    inv_y = np.concatenate((test[:, 235:239], test_y), axis=1)
    inv_y = scaler.inverse_transform(inv_y)
    inv_y = inv_y[:,-1]
    inv_yhat_gte_zero = inv_yhat.copy()
    inv_yhat_gte_zero[inv_yhat_gte_zero < 0] = 0

    # calculate r2
    result[0, i] = r2_score(inv_y, inv_yhat)

    # calculate mean absolute error
    result[1, i] = mean_absolute_error(inv_y, inv_yhat)

    # calculate rmse
    rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))
    result[2, i]= rmse

    # calculate mean absolute error percentage
    maep = np.mean(np.abs((inv_y - inv_yhat)/inv_y))*100
    result[3, i] = maep
    
    #train bias
    yhat_t = model.predict(train_X)
    # reshape back to 2d
    train_X = train_X.reshape((train_X.shape[0], -1))

    # invert scaling for forecast# invert 
    inv_yhat_t = np.concatenate((train[:, 235:239], yhat_t), axis=1)
    inv_yhat_t = scaler.inverse_transform(inv_yhat_t)
    inv_yhat_t = inv_yhat_t[:,-1]

    # invert scaling for actual
    train_y = train_y.reshape((len(train_y), 1))
    inv_y_t = np.concatenate((train[:, 235:239], train_y), axis=1)
    inv_y_t = scaler.inverse_transform(inv_y_t)
    inv_y_t = inv_y_t[:,-1]
    inv_yhat_gte_zero = inv_yhat_t.copy()
    inv_yhat_gte_zero[inv_yhat_gte_zero < 0] = 0

    index = (np.abs((inv_y_t - inv_yhat_t)/inv_y_t) < 1)
    # calculate mean absolute error percentage
    maep = np.mean(np.abs((inv_y_t[index] - inv_yhat_t[index])/inv_y_t[index]))*100
    
    result[4, i] = maep
# Out:
# Train on 225257 samples, validate on 55543 samples
# Epoch 1/100
#  - 73s - loss: 0.0242 - val_loss: 0.0210
# Epoch 2/100
#  - 91s - loss: 0.0166 - val_loss: 0.0142
# Epoch 3/100
#  - 90s - loss: 0.0162 - val_loss: 0.0145
# Epoch 4/100
#  - 90s - loss: 0.0155 - val_loss: 0.0132
# Epoch 5/100
#  - 92s - loss: 0.0151 - val_loss: 0.0151
# Epoch 6/100
#  - 90s - loss: 0.0149 - val_loss: 0.0151
# Epoch 7/100
#  - 91s - loss: 0.0149 - val_loss: 0.0129
# Epoch 8/100
#  - 91s - loss: 0.0146 - val_loss: 0.0127
# Epoch 9/100
#  - 91s - loss: 0.0146 - val_loss: 0.0125
# Epoch 10/100
#  - 91s - loss: 0.0144 - val_loss: 0.0126
# Epoch 11/100
#  - 91s - loss: 0.0144 - val_loss: 0.0150
# Epoch 12/100
#  - 91s - loss: 0.0145 - val_loss: 0.0154
# Epoch 13/100
#  - 92s - loss: 0.0144 - val_loss: 0.0171
# Epoch 14/100
#  - 91s - loss: 0.0145 - val_loss: 0.0123
# Epoch 15/100
#  - 92s - loss: 0.0144 - val_loss: 0.0183
# Epoch 16/100
#  - 91s - loss: 0.0143 - val_loss: 0.0161
# Epoch 17/100
#  - 92s - loss: 0.0144 - val_loss: 0.0131
# Epoch 18/100
#  - 92s - loss: 0.0142 - val_loss: 0.0129
# Epoch 19/100
#  - 92s - loss: 0.0143 - val_loss: 0.0126
# Epoch 20/100
#  - 92s - loss: 0.0142 - val_loss: 0.0168
# Epoch 21/100
#  - 92s - loss: 0.0143 - val_loss: 0.0154
# Epoch 22/100
#  - 91s - loss: 0.0143 - val_loss: 0.0144
# Epoch 23/100
#  - 92s - loss: 0.0143 - val_loss: 0.0144
# Epoch 24/100
#  - 92s - loss: 0.0143 - val_loss: 0.0140
# Epoch 25/100
#  - 92s - loss: 0.0143 - val_loss: 0.0196
# Epoch 26/100
#  - 91s - loss: 0.0143 - val_loss: 0.0187
# Epoch 27/100
#  - 93s - loss: 0.0143 - val_loss: 0.0196
# Epoch 28/100
#  - 91s - loss: 0.0143 - val_loss: 0.0155
# Epoch 29/100
#  - 92s - loss: 0.0142 - val_loss: 0.0200
# Epoch 30/100
#  - 91s - loss: 0.0142 - val_loss: 0.0194
# Epoch 31/100
#  - 93s - loss: 0.0143 - val_loss: 0.0133
# Epoch 32/100
#  - 91s - loss: 0.0142 - val_loss: 0.0159
# Epoch 33/100
#  - 92s - loss: 0.0141 - val_loss: 0.0161
# Epoch 34/100
#  - 91s - loss: 0.0143 - val_loss: 0.0155
# Epoch 35/100
#  - 93s - loss: 0.0141 - val_loss: 0.0164
# Epoch 36/100
#  - 91s - loss: 0.0142 - val_loss: 0.0189
# Epoch 37/100
#  - 92s - loss: 0.0142 - val_loss: 0.0137
# Epoch 38/100
#  - 91s - loss: 0.0141 - val_loss: 0.0223
# Epoch 39/100
#  - 92s - loss: 0.0141 - val_loss: 0.0246
# Epoch 40/100
#  - 92s - loss: 0.0142 - val_loss: 0.0135
# Epoch 41/100
#  - 92s - loss: 0.0142 - val_loss: 0.0183
# Epoch 42/100
#  - 91s - loss: 0.0142 - val_loss: 0.0217
# Epoch 43/100
#  - 90s - loss: 0.0142 - val_loss: 0.0198
# Epoch 44/100
#  - 89s - loss: 0.0142 - val_loss: 0.0253
# Epoch 45/100
#  - 90s - loss: 0.0142 - val_loss: 0.0155
# Epoch 46/100
#  - 89s - loss: 0.0141 - val_loss: 0.0201
# Epoch 47/100
#  - 90s - loss: 0.0141 - val_loss: 0.0228
# Epoch 48/100
#  - 89s - loss: 0.0141 - val_loss: 0.0179
# Epoch 49/100
#  - 90s - loss: 0.0141 - val_loss: 0.0142
# Epoch 50/100
#  - 89s - loss: 0.0141 - val_loss: 0.0216
# Epoch 51/100
#  - 90s - loss: 0.0141 - val_loss: 0.0153
# Epoch 52/100
#  - 90s - loss: 0.0141 - val_loss: 0.0142
# Epoch 53/100
#  - 90s - loss: 0.0141 - val_loss: 0.0131
# Epoch 54/100
#  - 89s - loss: 0.0141 - val_loss: 0.0205
# Epoch 55/100
#  - 90s - loss: 0.0141 - val_loss: 0.0201
# Epoch 56/100
#  - 88s - loss: 0.0141 - val_loss: 0.0130
# Epoch 57/100
#  - 89s - loss: 0.0141 - val_loss: 0.0133
# Epoch 58/100
#  - 88s - loss: 0.0140 - val_loss: 0.0125
# Epoch 59/100
#  - 86s - loss: 0.0140 - val_loss: 0.0143
# Epoch 60/100
#  - 86s - loss: 0.0141 - val_loss: 0.0129
# Epoch 61/100
#  - 92s - loss: 0.0140 - val_loss: 0.0135
# Epoch 62/100
#  - 91s - loss: 0.0140 - val_loss: 0.0131
# Epoch 63/100
#  - 91s - loss: 0.0140 - val_loss: 0.0133
# Epoch 64/100
#  - 92s - loss: 0.0140 - val_loss: 0.0125
# Epoch 65/100
#  - 92s - loss: 0.0140 - val_loss: 0.0130
# Epoch 66/100
#  - 92s - loss: 0.0140 - val_loss: 0.0128
# Epoch 67/100
#  - 92s - loss: 0.0140 - val_loss: 0.0135
# Epoch 68/100
#  - 92s - loss: 0.0140 - val_loss: 0.0132
# Epoch 69/100
#  - 92s - loss: 0.0140 - val_loss: 0.0124
# Epoch 70/100
#  - 92s - loss: 0.0140 - val_loss: 0.0132
# Epoch 71/100
#  - 92s - loss: 0.0140 - val_loss: 0.0124
# Epoch 72/100
#  - 91s - loss: 0.0140 - val_loss: 0.0124
# Epoch 73/100
#  - 92s - loss: 0.0140 - val_loss: 0.0132
# Epoch 74/100
#  - 91s - loss: 0.0140 - val_loss: 0.0129
# Epoch 75/100
#  - 93s - loss: 0.0140 - val_loss: 0.0138
# Epoch 76/100
#  - 92s - loss: 0.0140 - val_loss: 0.0122
# Epoch 77/100
#  - 92s - loss: 0.0139 - val_loss: 0.0128
# Epoch 78/100
#  - 91s - loss: 0.0140 - val_loss: 0.0122
# Epoch 79/100
#  - 92s - loss: 0.0140 - val_loss: 0.0123
# Epoch 80/100
#  - 91s - loss: 0.0140 - val_loss: 0.0127
# Epoch 81/100
#  - 91s - loss: 0.0139 - val_loss: 0.0132
# Epoch 82/100
#  - 91s - loss: 0.0139 - val_loss: 0.0128
# Epoch 83/100
#  - 92s - loss: 0.0140 - val_loss: 0.0123
# Epoch 84/100
#  - 92s - loss: 0.0139 - val_loss: 0.0124
# Epoch 85/100
#  - 92s - loss: 0.0139 - val_loss: 0.0122
# Epoch 86/100
#  - 92s - loss: 0.0139 - val_loss: 0.0124
# Epoch 87/100
#  - 92s - loss: 0.0139 - val_loss: 0.0123
# Epoch 88/100
#  - 92s - loss: 0.0139 - val_loss: 0.0122
# Epoch 89/100
#  - 92s - loss: 0.0139 - val_loss: 0.0121
# Epoch 90/100
#  - 92s - loss: 0.0140 - val_loss: 0.0121
# Epoch 91/100
#  - 93s - loss: 0.0139 - val_loss: 0.0122
# Epoch 92/100
#  - 92s - loss: 0.0139 - val_loss: 0.0123
# Epoch 93/100
#  - 92s - loss: 0.0139 - val_loss: 0.0122
# Epoch 94/100
#  - 93s - loss: 0.0139 - val_loss: 0.0121
# Epoch 95/100
#  - 92s - loss: 0.0139 - val_loss: 0.0122
# Epoch 96/100
#  - 93s - loss: 0.0139 - val_loss: 0.0122
# Epoch 97/100
#  - 92s - loss: 0.0139 - val_loss: 0.0122
# Epoch 98/100
#  - 93s - loss: 0.0139 - val_loss: 0.0122
# Epoch 99/100
#  - 92s - loss: 0.0139 - val_loss: 0.0125
# Epoch 100/100
#  - 93s - loss: 0.0139 - val_loss: 0.0122
# Train on 225257 samples, validate on 55543 samples
# Epoch 1/100
#  - 93s - loss: 0.0253 - val_loss: 0.0263
# Epoch 2/100
#  - 92s - loss: 0.0169 - val_loss: 0.0142
# Epoch 3/100
#  - 93s - loss: 0.0157 - val_loss: 0.0141
# Epoch 4/100
#  - 93s - loss: 0.0153 - val_loss: 0.0146
# Epoch 5/100
#  - 93s - loss: 0.0154 - val_loss: 0.0136
# Epoch 6/100
#  - 92s - loss: 0.0148 - val_loss: 0.0141
# Epoch 7/100
#  - 93s - loss: 0.0148 - val_loss: 0.0126
# Epoch 8/100
#  - 92s - loss: 0.0147 - val_loss: 0.0126
# Epoch 9/100
#  - 93s - loss: 0.0146 - val_loss: 0.0143
# Epoch 10/100
#  - 92s - loss: 0.0147 - val_loss: 0.0129
# Epoch 11/100
#  - 92s - loss: 0.0143 - val_loss: 0.0146
# Epoch 12/100
#  - 92s - loss: 0.0145 - val_loss: 0.0130
# Epoch 13/100
#  - 93s - loss: 0.0144 - val_loss: 0.0125
# Epoch 14/100
#  - 92s - loss: 0.0145 - val_loss: 0.0179
# Epoch 15/100
#  - 93s - loss: 0.0145 - val_loss: 0.0134
# Epoch 16/100
#  - 92s - loss: 0.0144 - val_loss: 0.0185
# Epoch 17/100
#  - 93s - loss: 0.0144 - val_loss: 0.0127
# Epoch 18/100
#  - 92s - loss: 0.0143 - val_loss: 0.0207
# Epoch 19/100
#  - 93s - loss: 0.0144 - val_loss: 0.0161
# Epoch 20/100
#  - 92s - loss: 0.0143 - val_loss: 0.0126
# Epoch 21/100
#  - 93s - loss: 0.0143 - val_loss: 0.0148
# Epoch 22/100
#  - 92s - loss: 0.0142 - val_loss: 0.0160
# Epoch 23/100
#  - 93s - loss: 0.0143 - val_loss: 0.0164
# Epoch 24/100
#  - 92s - loss: 0.0143 - val_loss: 0.0164
# Epoch 25/100
#  - 93s - loss: 0.0143 - val_loss: 0.0151
# Epoch 26/100
#  - 92s - loss: 0.0142 - val_loss: 0.0203
# Epoch 27/100
#  - 92s - loss: 0.0142 - val_loss: 0.0146
# Epoch 28/100
#  - 92s - loss: 0.0143 - val_loss: 0.0129
# Epoch 29/100
#  - 93s - loss: 0.0142 - val_loss: 0.0143
# Epoch 30/100
#  - 92s - loss: 0.0142 - val_loss: 0.0145
# Epoch 31/100
#  - 92s - loss: 0.0142 - val_loss: 0.0200
# Epoch 32/100
#  - 92s - loss: 0.0142 - val_loss: 0.0149
# Epoch 33/100
#  - 92s - loss: 0.0142 - val_loss: 0.0154
# Epoch 34/100
#  - 92s - loss: 0.0142 - val_loss: 0.0221
# Epoch 35/100
#  - 92s - loss: 0.0144 - val_loss: 0.0187
# Epoch 36/100
#  - 92s - loss: 0.0142 - val_loss: 0.0179
# Epoch 37/100
#  - 93s - loss: 0.0142 - val_loss: 0.0162
# Epoch 38/100
#  - 92s - loss: 0.0142 - val_loss: 0.0226
# Epoch 39/100
#  - 92s - loss: 0.0143 - val_loss: 0.0221
# Epoch 40/100
#  - 92s - loss: 0.0143 - val_loss: 0.0178
# Epoch 41/100
#  - 93s - loss: 0.0143 - val_loss: 0.0174
# Epoch 42/100
#  - 92s - loss: 0.0142 - val_loss: 0.0170
# Epoch 43/100
#  - 93s - loss: 0.0144 - val_loss: 0.0138
# Epoch 44/100
#  - 93s - loss: 0.0141 - val_loss: 0.0168
# Epoch 45/100
#  - 92s - loss: 0.0142 - val_loss: 0.0148
# Epoch 46/100
#  - 93s - loss: 0.0141 - val_loss: 0.0176
# Epoch 47/100
#  - 92s - loss: 0.0141 - val_loss: 0.0144
# Epoch 48/100
#  - 93s - loss: 0.0141 - val_loss: 0.0135
# Epoch 49/100
#  - 92s - loss: 0.0141 - val_loss: 0.0154
# Epoch 50/100
#  - 93s - loss: 0.0141 - val_loss: 0.0178
# Epoch 51/100
#  - 92s - loss: 0.0142 - val_loss: 0.0132
# Epoch 52/100
#  - 93s - loss: 0.0142 - val_loss: 0.0122
# Epoch 53/100
#  - 92s - loss: 0.0141 - val_loss: 0.0130
# Epoch 54/100
#  - 92s - loss: 0.0141 - val_loss: 0.0135
# Epoch 55/100
#  - 92s - loss: 0.0141 - val_loss: 0.0135
# Epoch 56/100
#  - 93s - loss: 0.0141 - val_loss: 0.0136
# Epoch 57/100
#  - 92s - loss: 0.0141 - val_loss: 0.0133
# Epoch 58/100
#  - 93s - loss: 0.0141 - val_loss: 0.0122
# Epoch 59/100
#  - 92s - loss: 0.0141 - val_loss: 0.0123
# Epoch 60/100
#  - 93s - loss: 0.0141 - val_loss: 0.0121
# Epoch 61/100
#  - 92s - loss: 0.0140 - val_loss: 0.0126
# Epoch 62/100
#  - 93s - loss: 0.0140 - val_loss: 0.0139
# Epoch 63/100
#  - 91s - loss: 0.0141 - val_loss: 0.0123
# Epoch 64/100
#  - 93s - loss: 0.0140 - val_loss: 0.0122
# Epoch 65/100
#  - 92s - loss: 0.0140 - val_loss: 0.0124
# Epoch 66/100
#  - 93s - loss: 0.0140 - val_loss: 0.0131
# Epoch 67/100
#  - 91s - loss: 0.0140 - val_loss: 0.0122
# Epoch 68/100
#  - 90s - loss: 0.0140 - val_loss: 0.0123
# Epoch 69/100
#  - 89s - loss: 0.0140 - val_loss: 0.0124
# Epoch 70/100
#  - 90s - loss: 0.0140 - val_loss: 0.0123
# Epoch 71/100
#  - 89s - loss: 0.0140 - val_loss: 0.0122
# Epoch 72/100
#  - 90s - loss: 0.0140 - val_loss: 0.0122
# Epoch 73/100
#  - 89s - loss: 0.0140 - val_loss: 0.0122
# Epoch 74/100
#  - 90s - loss: 0.0140 - val_loss: 0.0122
# Epoch 75/100
#  - 90s - loss: 0.0140 - val_loss: 0.0122
# Epoch 76/100
#  - 90s - loss: 0.0140 - val_loss: 0.0126
# Epoch 77/100
#  - 89s - loss: 0.0140 - val_loss: 0.0123
# Epoch 78/100
#  - 90s - loss: 0.0140 - val_loss: 0.0122
# Epoch 79/100
#  - 89s - loss: 0.0139 - val_loss: 0.0123
# Epoch 80/100
#  - 90s - loss: 0.0140 - val_loss: 0.0127
# Epoch 81/100
#  - 89s - loss: 0.0140 - val_loss: 0.0129
# Epoch 82/100
#  - 90s - loss: 0.0139 - val_loss: 0.0126
# Epoch 83/100
#  - 86s - loss: 0.0139 - val_loss: 0.0123
# Epoch 84/100
#  - 87s - loss: 0.0140 - val_loss: 0.0131
# Epoch 85/100
#  - 91s - loss: 0.0139 - val_loss: 0.0123
# Epoch 86/100
#  - 92s - loss: 0.0140 - val_loss: 0.0130
# Epoch 87/100
#  - 91s - loss: 0.0139 - val_loss: 0.0127
# Epoch 88/100
#  - 92s - loss: 0.0139 - val_loss: 0.0127
# Epoch 89/100
#  - 91s - loss: 0.0139 - val_loss: 0.0126
# Epoch 90/100
#  - 92s - loss: 0.0139 - val_loss: 0.0126
# Epoch 91/100
#  - 92s - loss: 0.0139 - val_loss: 0.0125
# Epoch 92/100
#  - 92s - loss: 0.0139 - val_loss: 0.0125
# Epoch 93/100
#  - 92s - loss: 0.0139 - val_loss: 0.0125
# Epoch 94/100
#  - 93s - loss: 0.0139 - val_loss: 0.0133
# Epoch 95/100
#  - 92s - loss: 0.0139 - val_loss: 0.0124
# Epoch 96/100
#  - 92s - loss: 0.0139 - val_loss: 0.0128
# Epoch 97/100
#  - 91s - loss: 0.0139 - val_loss: 0.0127
# Epoch 98/100
#  - 92s - loss: 0.0139 - val_loss: 0.0128
# Epoch 99/100
#  - 92s - loss: 0.0139 - val_loss: 0.0125
# Epoch 100/100
#  - 92s - loss: 0.0139 - val_loss: 0.0129
# Train on 225257 samples, validate on 55543 samples
# Epoch 1/100
#  - 94s - loss: 0.0240 - val_loss: 0.0230
# Epoch 2/100
#  - 92s - loss: 0.0169 - val_loss: 0.0307
# Epoch 3/100
#  - 92s - loss: 0.0160 - val_loss: 0.0159
# Epoch 4/100
#  - 92s - loss: 0.0153 - val_loss: 0.0264
# Epoch 5/100
#  - 92s - loss: 0.0156 - val_loss: 0.0149
# Epoch 6/100
#  - 92s - loss: 0.0149 - val_loss: 0.0164
# Epoch 7/100
#  - 92s - loss: 0.0147 - val_loss: 0.0207
# Epoch 8/100
#  - 92s - loss: 0.0148 - val_loss: 0.0124
# Epoch 9/100
#  - 92s - loss: 0.0146 - val_loss: 0.0124
# Epoch 10/100
#  - 92s - loss: 0.0145 - val_loss: 0.0142
# Epoch 11/100
#  - 93s - loss: 0.0144 - val_loss: 0.0131
# Epoch 12/100
#  - 92s - loss: 0.0145 - val_loss: 0.0162
# Epoch 13/100
#  - 93s - loss: 0.0145 - val_loss: 0.0151
# Epoch 14/100
#  - 92s - loss: 0.0145 - val_loss: 0.0135
# Epoch 15/100
#  - 92s - loss: 0.0144 - val_loss: 0.0174
# Epoch 16/100
#  - 92s - loss: 0.0144 - val_loss: 0.0128
# Epoch 17/100
#  - 93s - loss: 0.0143 - val_loss: 0.0159
# Epoch 18/100
#  - 92s - loss: 0.0144 - val_loss: 0.0152
# Epoch 19/100
#  - 92s - loss: 0.0143 - val_loss: 0.0156
# Epoch 20/100
#  - 92s - loss: 0.0144 - val_loss: 0.0193
# Epoch 21/100
#  - 93s - loss: 0.0143 - val_loss: 0.0170
# Epoch 22/100
#  - 91s - loss: 0.0144 - val_loss: 0.0204
# Epoch 23/100
#  - 93s - loss: 0.0144 - val_loss: 0.0181
# Epoch 24/100
#  - 92s - loss: 0.0143 - val_loss: 0.0165
# Epoch 25/100
#  - 93s - loss: 0.0143 - val_loss: 0.0161
# Epoch 26/100
#  - 92s - loss: 0.0142 - val_loss: 0.0139
# Epoch 27/100
#  - 93s - loss: 0.0143 - val_loss: 0.0159
# Epoch 28/100
#  - 92s - loss: 0.0142 - val_loss: 0.0201
# Epoch 29/100
#  - 92s - loss: 0.0142 - val_loss: 0.0157
# Epoch 30/100
#  - 92s - loss: 0.0142 - val_loss: 0.0168
# Epoch 31/100
#  - 92s - loss: 0.0143 - val_loss: 0.0191
# Epoch 32/100
#  - 93s - loss: 0.0143 - val_loss: 0.0186
# Epoch 33/100
#  - 91s - loss: 0.0142 - val_loss: 0.0150
# Epoch 34/100
#  - 93s - loss: 0.0142 - val_loss: 0.0169
# Epoch 35/100
#  - 92s - loss: 0.0142 - val_loss: 0.0224
# Epoch 36/100
#  - 93s - loss: 0.0143 - val_loss: 0.0201
# Epoch 37/100
#  - 92s - loss: 0.0143 - val_loss: 0.0220
# Epoch 38/100
#  - 93s - loss: 0.0142 - val_loss: 0.0241
# Epoch 39/100
#  - 92s - loss: 0.0143 - val_loss: 0.0164
# Epoch 40/100
#  - 93s - loss: 0.0142 - val_loss: 0.0181
# Epoch 41/100
#  - 92s - loss: 0.0143 - val_loss: 0.0147
# Epoch 42/100
#  - 94s - loss: 0.0142 - val_loss: 0.0198
# Epoch 43/100
#  - 93s - loss: 0.0143 - val_loss: 0.0159
# Epoch 44/100
#  - 93s - loss: 0.0141 - val_loss: 0.0176
# Epoch 45/100
#  - 92s - loss: 0.0141 - val_loss: 0.0177
# Epoch 46/100
#  - 93s - loss: 0.0142 - val_loss: 0.0140
# Epoch 47/100
#  - 92s - loss: 0.0141 - val_loss: 0.0165
# Epoch 48/100
#  - 93s - loss: 0.0141 - val_loss: 0.0151
# Epoch 49/100
#  - 92s - loss: 0.0141 - val_loss: 0.0139
# Epoch 50/100
#  - 93s - loss: 0.0141 - val_loss: 0.0136
# Epoch 51/100
#  - 92s - loss: 0.0141 - val_loss: 0.0128
# Epoch 52/100
#  - 92s - loss: 0.0141 - val_loss: 0.0126
# Epoch 53/100
#  - 92s - loss: 0.0140 - val_loss: 0.0136
# Epoch 54/100
#  - 92s - loss: 0.0141 - val_loss: 0.0123
# Epoch 55/100
#  - 92s - loss: 0.0140 - val_loss: 0.0140
# Epoch 56/100
#  - 92s - loss: 0.0141 - val_loss: 0.0124
# Epoch 57/100
#  - 92s - loss: 0.0141 - val_loss: 0.0123
# Epoch 58/100
#  - 92s - loss: 0.0140 - val_loss: 0.0124
# Epoch 59/100
#  - 92s - loss: 0.0140 - val_loss: 0.0144
# Epoch 60/100
#  - 92s - loss: 0.0140 - val_loss: 0.0138
# Epoch 61/100
#  - 91s - loss: 0.0140 - val_loss: 0.0154
# Epoch 62/100
#  - 92s - loss: 0.0141 - val_loss: 0.0124
# Epoch 63/100
#  - 92s - loss: 0.0140 - val_loss: 0.0129
# Epoch 64/100
#  - 92s - loss: 0.0139 - val_loss: 0.0143
# Epoch 65/100
#  - 92s - loss: 0.0140 - val_loss: 0.0138
# Epoch 66/100
#  - 93s - loss: 0.0140 - val_loss: 0.0127
# Epoch 67/100
#  - 91s - loss: 0.0140 - val_loss: 0.0130
# Epoch 68/100
#  - 93s - loss: 0.0140 - val_loss: 0.0126
# Epoch 69/100
#  - 92s - loss: 0.0140 - val_loss: 0.0122
# Epoch 70/100
#  - 91s - loss: 0.0140 - val_loss: 0.0128
# Epoch 71/100
#  - 93s - loss: 0.0140 - val_loss: 0.0126
# Epoch 72/100
#  - 92s - loss: 0.0140 - val_loss: 0.0123
# Epoch 73/100
#  - 92s - loss: 0.0140 - val_loss: 0.0122
# Epoch 74/100
#  - 92s - loss: 0.0140 - val_loss: 0.0131
# Epoch 75/100
#  - 92s - loss: 0.0140 - val_loss: 0.0122
# Epoch 76/100
#  - 92s - loss: 0.0139 - val_loss: 0.0126
# Epoch 77/100
#  - 92s - loss: 0.0140 - val_loss: 0.0121
# Epoch 78/100
#  - 92s - loss: 0.0139 - val_loss: 0.0126
# Epoch 79/100
#  - 92s - loss: 0.0139 - val_loss: 0.0122
# Epoch 80/100
#  - 92s - loss: 0.0140 - val_loss: 0.0126
# Epoch 81/100
#  - 92s - loss: 0.0140 - val_loss: 0.0122
# Epoch 82/100
#  - 91s - loss: 0.0140 - val_loss: 0.0126
# Epoch 83/100
#  - 92s - loss: 0.0139 - val_loss: 0.0124
# Epoch 84/100
#  - 92s - loss: 0.0139 - val_loss: 0.0122
# Epoch 85/100
#  - 92s - loss: 0.0139 - val_loss: 0.0130
# Epoch 86/100
#  - 92s - loss: 0.0139 - val_loss: 0.0124
# Epoch 87/100
#  - 92s - loss: 0.0139 - val_loss: 0.0124
# Epoch 88/100
#  - 92s - loss: 0.0139 - val_loss: 0.0122
# Epoch 89/100
#  - 92s - loss: 0.0139 - val_loss: 0.0128
# Epoch 90/100
#  - 90s - loss: 0.0139 - val_loss: 0.0128
# Epoch 91/100
#  - 90s - loss: 0.0139 - val_loss: 0.0122
# Epoch 92/100
#  - 90s - loss: 0.0139 - val_loss: 0.0126
# Epoch 93/100
#  - 90s - loss: 0.0139 - val_loss: 0.0121
# Epoch 94/100
#  - 90s - loss: 0.0139 - val_loss: 0.0123
# Epoch 95/100
#  - 90s - loss: 0.0139 - val_loss: 0.0122
# Epoch 96/100
#  - 89s - loss: 0.0140 - val_loss: 0.0124
# Epoch 97/100
#  - 90s - loss: 0.0139 - val_loss: 0.0123
# Epoch 98/100
#  - 90s - loss: 0.0139 - val_loss: 0.0122
# Epoch 99/100
#  - 91s - loss: 0.0139 - val_loss: 0.0122
# Epoch 100/100
#  - 89s - loss: 0.0139 - val_loss: 0.0125

# %%
result
# Out:
# array([[ 0.        ,  0.        ,  0.        ,  0.        ,  0.97714602,
#          0.97486044,  0.97641418],
#        [ 0.        ,  0.        ,  0.        ,  0.        , 12.31688881,
#         13.02807331, 12.5700016 ],
#        [ 0.        ,  0.        ,  0.        ,  0.        , 16.19019475,
#         16.98048268, 16.44737869],
#        [ 0.        ,  0.        ,  0.        ,  0.        ,  7.35767633,
#          8.09993744,  7.60046765],
#        [ 0.        ,  0.        ,  0.        ,  0.        ,  6.62987456,
#          6.54872656,  6.42831773]])
