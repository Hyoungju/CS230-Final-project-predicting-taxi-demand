# %%
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, Normalizer
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %matplotlib inline
# plt.style.use("ggplot")
sns.set_style("darkgrid")
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
data = pd.read_csv("final_without_weather.csv")
data.drop(['Month'], axis =1, inplace= True)
data.set_index("pickuptime", inplace= True)
num_pickups = data.total
num_green_pickups = data.green
num_yellow_pickups = data.yellow
data.drop(['green', 'yellow', 'total'], axis =1, inplace = True)

# %%
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    
    agg = pd.concat(cols, axis = 1)
    agg.columns = names
    
    if dropnan:
        agg.dropna(inplace = True)
        
    return agg

# %% [markdown]
# Time sequence 24hours(from 23 hours get 1 hours)

# %%
#normalize data & make LSTM model structure
features_and_target = pd.concat([data, num_pickups], axis = 1)
values = features_and_target.values

values = values.astype('float32')

scaler = MinMaxScaler(feature_range = (0, 1))
scaled = scaler.fit_transform(values)

n_hours = 23

reframed = series_to_supervised(scaled, n_hours, 1)

n_features = features_and_target.shape[1]

# %%
# exlcude significantly deviated data
total_values = reframed.values
n_p = np.argmin(total_values[365*24*3:, -1])
n_p = n_p + 365*24*3

a = total_values[: n_p, :]
b = total_values[n_p + n_hours + 1 : , :]
values = np.concatenate((a, b), axis=0)

# %%
# split into train and test sets 
n_train_hours = 365 * 24 * 3
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
n_obs = n_hours * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (26280, 115) 26280 (26280,)
# (26280, 23, 5) (26280,) (6517, 23, 5) (6517,)

# %%
# design network
model = Sequential()
model.add(LSTM(24, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

# fit network
history = model.fit(train_X, train_y, epochs=100, batch_size=100,
                    validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Train on 26280 samples, validate on 6517 samples
# Epoch 1/100
#  - 6s - loss: 0.0803 - val_loss: 0.0437
# Epoch 2/100
#  - 5s - loss: 0.0500 - val_loss: 0.0322
# Epoch 3/100
#  - 5s - loss: 0.0393 - val_loss: 0.0344
# Epoch 4/100
#  - 5s - loss: 0.0351 - val_loss: 0.0292
# Epoch 5/100
#  - 5s - loss: 0.0324 - val_loss: 0.0265
# Epoch 6/100
#  - 5s - loss: 0.0300 - val_loss: 0.0240
# Epoch 7/100
#  - 5s - loss: 0.0283 - val_loss: 0.0216
# Epoch 8/100
#  - 5s - loss: 0.0275 - val_loss: 0.0215
# Epoch 9/100
#  - 5s - loss: 0.0267 - val_loss: 0.0209
# Epoch 10/100
#  - 5s - loss: 0.0259 - val_loss: 0.0203
# Epoch 11/100
#  - 5s - loss: 0.0248 - val_loss: 0.0193
# Epoch 12/100
#  - 5s - loss: 0.0242 - val_loss: 0.0189
# Epoch 13/100
#  - 5s - loss: 0.0236 - val_loss: 0.0193
# Epoch 14/100
#  - 5s - loss: 0.0230 - val_loss: 0.0189
# Epoch 15/100
#  - 5s - loss: 0.0224 - val_loss: 0.0188
# Epoch 16/100
#  - 5s - loss: 0.0217 - val_loss: 0.0185
# Epoch 17/100
#  - 5s - loss: 0.0212 - val_loss: 0.0176
# Epoch 18/100
#  - 5s - loss: 0.0208 - val_loss: 0.0171
# Epoch 19/100
#  - 5s - loss: 0.0204 - val_loss: 0.0166
# Epoch 20/100
#  - 5s - loss: 0.0201 - val_loss: 0.0165
# Epoch 21/100
#  - 6s - loss: 0.0198 - val_loss: 0.0163
# Epoch 22/100
#  - 5s - loss: 0.0195 - val_loss: 0.0161
# Epoch 23/100
#  - 5s - loss: 0.0192 - val_loss: 0.0159
# Epoch 24/100
#  - 5s - loss: 0.0188 - val_loss: 0.0155
# Epoch 25/100
#  - 5s - loss: 0.0184 - val_loss: 0.0153
# Epoch 26/100
#  - 5s - loss: 0.0181 - val_loss: 0.0157
# Epoch 27/100
#  - 5s - loss: 0.0178 - val_loss: 0.0153
# Epoch 28/100
#  - 5s - loss: 0.0176 - val_loss: 0.0154
# Epoch 29/100
#  - 5s - loss: 0.0174 - val_loss: 0.0160
# Epoch 30/100
#  - 5s - loss: 0.0171 - val_loss: 0.0155
# Epoch 31/100
#  - 5s - loss: 0.0169 - val_loss: 0.0165
# Epoch 32/100
#  - 5s - loss: 0.0168 - val_loss: 0.0160
# Epoch 33/100
#  - 5s - loss: 0.0167 - val_loss: 0.0162
# Epoch 34/100
#  - 5s - loss: 0.0165 - val_loss: 0.0160
# Epoch 35/100
#  - 5s - loss: 0.0164 - val_loss: 0.0162
# Epoch 36/100
#  - 5s - loss: 0.0162 - val_loss: 0.0160
# Epoch 37/100
#  - 5s - loss: 0.0161 - val_loss: 0.0161
# Epoch 38/100
#  - 5s - loss: 0.0160 - val_loss: 0.0161
# Epoch 39/100
#  - 5s - loss: 0.0160 - val_loss: 0.0160
# Epoch 40/100
#  - 5s - loss: 0.0158 - val_loss: 0.0161
# Epoch 41/100
#  - 5s - loss: 0.0158 - val_loss: 0.0161
# Epoch 42/100
#  - 5s - loss: 0.0157 - val_loss: 0.0159
# Epoch 43/100
#  - 5s - loss: 0.0157 - val_loss: 0.0158
# Epoch 44/100
#  - 5s - loss: 0.0156 - val_loss: 0.0158
# Epoch 45/100
#  - 5s - loss: 0.0155 - val_loss: 0.0158
# Epoch 46/100
#  - 5s - loss: 0.0154 - val_loss: 0.0159
# Epoch 47/100
#  - 5s - loss: 0.0153 - val_loss: 0.0161
# Epoch 48/100
#  - 5s - loss: 0.0152 - val_loss: 0.0158
# Epoch 49/100
#  - 5s - loss: 0.0151 - val_loss: 0.0160
# Epoch 50/100
#  - 5s - loss: 0.0150 - val_loss: 0.0164
# Epoch 51/100
#  - 5s - loss: 0.0150 - val_loss: 0.0158
# Epoch 52/100
#  - 5s - loss: 0.0149 - val_loss: 0.0159
# Epoch 53/100
#  - 5s - loss: 0.0148 - val_loss: 0.0159
# Epoch 54/100
#  - 5s - loss: 0.0147 - val_loss: 0.0158
# Epoch 55/100
#  - 5s - loss: 0.0146 - val_loss: 0.0159
# Epoch 56/100
#  - 5s - loss: 0.0145 - val_loss: 0.0160
# Epoch 57/100
#  - 5s - loss: 0.0144 - val_loss: 0.0156
# Epoch 58/100
#  - 5s - loss: 0.0144 - val_loss: 0.0155
# Epoch 59/100
#  - 5s - loss: 0.0145 - val_loss: 0.0159
# Epoch 60/100
#  - 5s - loss: 0.0143 - val_loss: 0.0162
# Epoch 61/100
#  - 5s - loss: 0.0143 - val_loss: 0.0157
# Epoch 62/100
#  - 5s - loss: 0.0142 - val_loss: 0.0157
# Epoch 63/100
#  - 5s - loss: 0.0141 - val_loss: 0.0158
# Epoch 64/100
#  - 5s - loss: 0.0141 - val_loss: 0.0154
# Epoch 65/100
#  - 5s - loss: 0.0140 - val_loss: 0.0156
# Epoch 66/100
#  - 5s - loss: 0.0140 - val_loss: 0.0154
# Epoch 67/100
#  - 5s - loss: 0.0139 - val_loss: 0.0159
# Epoch 68/100
#  - 5s - loss: 0.0139 - val_loss: 0.0154
# Epoch 69/100
#  - 5s - loss: 0.0139 - val_loss: 0.0154
# Epoch 70/100
#  - 5s - loss: 0.0138 - val_loss: 0.0153
# Epoch 71/100
#  - 5s - loss: 0.0138 - val_loss: 0.0153
# Epoch 72/100
#  - 5s - loss: 0.0137 - val_loss: 0.0153
# Epoch 73/100
#  - 5s - loss: 0.0137 - val_loss: 0.0151
# Epoch 74/100
#  - 5s - loss: 0.0136 - val_loss: 0.0149
# Epoch 75/100
#  - 5s - loss: 0.0136 - val_loss: 0.0152
# Epoch 76/100
#  - 5s - loss: 0.0136 - val_loss: 0.0150
# Epoch 77/100
#  - 5s - loss: 0.0136 - val_loss: 0.0151
# Epoch 78/100
#  - 5s - loss: 0.0136 - val_loss: 0.0150
# Epoch 79/100
#  - 5s - loss: 0.0135 - val_loss: 0.0148
# Epoch 80/100
#  - 5s - loss: 0.0135 - val_loss: 0.0147
# Epoch 81/100
#  - 5s - loss: 0.0134 - val_loss: 0.0146
# Epoch 82/100
#  - 5s - loss: 0.0134 - val_loss: 0.0148
# Epoch 83/100
#  - 5s - loss: 0.0135 - val_loss: 0.0147
# Epoch 84/100
#  - 5s - loss: 0.0134 - val_loss: 0.0145
# Epoch 85/100
#  - 5s - loss: 0.0134 - val_loss: 0.0145
# Epoch 86/100
#  - 5s - loss: 0.0134 - val_loss: 0.0144
# Epoch 87/100
#  - 5s - loss: 0.0133 - val_loss: 0.0147
# Epoch 88/100
#  - 5s - loss: 0.0133 - val_loss: 0.0146
# Epoch 89/100
#  - 5s - loss: 0.0133 - val_loss: 0.0145
# Epoch 90/100
#  - 5s - loss: 0.0132 - val_loss: 0.0145
# Epoch 91/100
#  - 5s - loss: 0.0132 - val_loss: 0.0145
# Epoch 92/100
#  - 5s - loss: 0.0131 - val_loss: 0.0145
# Epoch 93/100
#  - 5s - loss: 0.0131 - val_loss: 0.0147
# Epoch 94/100
#  - 5s - loss: 0.0131 - val_loss: 0.0144
# Epoch 95/100
#  - 5s - loss: 0.0131 - val_loss: 0.0145
# Epoch 96/100
#  - 6s - loss: 0.0131 - val_loss: 0.0143
# Epoch 97/100
#  - 5s - loss: 0.0131 - val_loss: 0.0143
# Epoch 98/100
#  - 5s - loss: 0.0131 - val_loss: 0.0142
# Epoch 99/100
#  - 5s - loss: 0.0131 - val_loss: 0.0142
# Epoch 100/100
#  - 5s - loss: 0.0130 - val_loss: 0.0140

# %%
history_loss = pd.DataFrame()
history_loss['train'] = history.history['loss']
history_loss['test'] = history.history['val_loss']
history_loss.plot(figsize=(10,10), fontsize=16,
                title='LSTM Model Loss');

# %%
# make a prediction 
yhat = model.predict(test_X)
# reshape back to 2d
test_X = test_X.reshape((test_X.shape[0], -1))

# invert scaling for forecast# invert 
inv_yhat = np.concatenate((test[:, 115:119], yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]

# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test[:, 115:119], test_y), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]
inv_yhat_gte_zero = inv_yhat.copy()
inv_yhat_gte_zero[inv_yhat_gte_zero < 0] = 0

# calculate r2
print("R2:  ", r2_score(inv_y, inv_yhat))

# calculate mean absolute error
print("MAE: ", mean_absolute_error(inv_y, inv_yhat))

# calculate rmse
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))
print("RMSE:", rmse)

# calculate mean absolute error percentage
maep = np.mean(np.abs((inv_y - inv_yhat)/inv_y))*100
print("mean absolute error percentage: ", maep)
# Out:
# R2:   0.9715324670846391
# MAE:  784.1511
# RMSE: 1110.6265686539289
# mean absolute error percentage:  7.251535356044769

# %%
#train error(bias)
yhat_t = model.predict(train_X)
# reshape back to 2d
train_X = train_X.reshape((train_X.shape[0], -1))

# invert scaling for forecast
inv_yhat_t = np.concatenate((train[:, 115:119], yhat_t), axis=1)
inv_yhat_t = scaler.inverse_transform(inv_yhat_t)
inv_yhat_t = inv_yhat_t[:,-1]

# invert scaling for actual
train_y = train_y.reshape((len(train_y), 1))
inv_y_t = np.concatenate((train[:, 115:119], train_y), axis=1)
inv_y_t = scaler.inverse_transform(inv_y_t)
inv_y_t = inv_y_t[:,-1]
inv_yhat_gte_zero = inv_yhat_t.copy()
inv_yhat_gte_zero[inv_yhat_gte_zero < 0] = 0

# exlcude significantly deviated data
index = (np.abs((inv_y_t - inv_yhat_t)/inv_y_t) < 1)

# calculate r2
print("R2:  ", r2_score(inv_y_t[index], inv_yhat_t[index]))

# calculate mean absolute error
print("MAE: ", mean_absolute_error(inv_y_t[index], inv_yhat_t[index]))

# calculate rmse
rmse = math.sqrt(mean_squared_error(inv_y_t[index], inv_yhat_t[index]))
print("RMSE:", rmse)

# calculate mean absolute error percentage
maep = np.mean(np.abs((inv_y_t[index] - inv_yhat_t[index])/inv_y_t[index]))*100
print("mean absolute error percentage: ", maep)
# Out:
# R2:   0.9683806754697961
# MAE:  1015.44415
# RMSE: 1511.9983465599425
# mean absolute error percentage:  6.435330957174301

# %% [markdown]
# Time sequence 12hours(from 11 hours get 1 hours)

# %%
#normalize data & make LSTM model structure
features_and_target = pd.concat([data, num_pickups], axis = 1)
values = features_and_target.values

values = values.astype('float32')

scaler = MinMaxScaler(feature_range = (0, 1))
scaled = scaler.fit_transform(values)

n_hours = 11

reframed = series_to_supervised(scaled, n_hours, 1)

n_features = features_and_target.shape[1]

# %%
# exlcude significantly deviated data
total_values = reframed.values
n_p = np.argmin(total_values[365*24*3:, -1])
n_p = n_p + 365*24*3

a = total_values[: n_p, :]
b = total_values[n_p + n_hours + 1 : , :]
values = np.concatenate((a, b), axis=0)

# %%
# split into train and test sets 
n_train_hours = 365 * 24 * 3
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
n_obs = n_hours * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (26280, 55) 26280 (26280,)
# (26280, 11, 5) (26280,) (6541, 11, 5) (6541,)

# %%
# design network
model = Sequential()
model.add(LSTM(24, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

# fit network
history = model.fit(train_X, train_y, epochs=100, batch_size=100,
                    validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Train on 26280 samples, validate on 6541 samples
# Epoch 1/100
#  - 3s - loss: 0.0854 - val_loss: 0.0511
# Epoch 2/100
#  - 3s - loss: 0.0590 - val_loss: 0.0450
# Epoch 3/100
#  - 3s - loss: 0.0430 - val_loss: 0.0281
# Epoch 4/100
#  - 2s - loss: 0.0383 - val_loss: 0.0285
# Epoch 5/100
#  - 2s - loss: 0.0351 - val_loss: 0.0265
# Epoch 6/100
#  - 3s - loss: 0.0324 - val_loss: 0.0250
# Epoch 7/100
#  - 3s - loss: 0.0307 - val_loss: 0.0235
# Epoch 8/100
#  - 3s - loss: 0.0290 - val_loss: 0.0230
# Epoch 9/100
#  - 3s - loss: 0.0277 - val_loss: 0.0221
# Epoch 10/100
#  - 3s - loss: 0.0268 - val_loss: 0.0208
# Epoch 11/100
#  - 3s - loss: 0.0260 - val_loss: 0.0204
# Epoch 12/100
#  - 3s - loss: 0.0254 - val_loss: 0.0201
# Epoch 13/100
#  - 2s - loss: 0.0250 - val_loss: 0.0207
# Epoch 14/100
#  - 2s - loss: 0.0248 - val_loss: 0.0202
# Epoch 15/100
#  - 2s - loss: 0.0245 - val_loss: 0.0200
# Epoch 16/100
#  - 2s - loss: 0.0243 - val_loss: 0.0199
# Epoch 17/100
#  - 3s - loss: 0.0240 - val_loss: 0.0199
# Epoch 18/100
#  - 3s - loss: 0.0238 - val_loss: 0.0199
# Epoch 19/100
#  - 2s - loss: 0.0237 - val_loss: 0.0195
# Epoch 20/100
#  - 3s - loss: 0.0233 - val_loss: 0.0193
# Epoch 21/100
#  - 3s - loss: 0.0231 - val_loss: 0.0190
# Epoch 22/100
#  - 3s - loss: 0.0231 - val_loss: 0.0190
# Epoch 23/100
#  - 2s - loss: 0.0227 - val_loss: 0.0191
# Epoch 24/100
#  - 2s - loss: 0.0226 - val_loss: 0.0192
# Epoch 25/100
#  - 2s - loss: 0.0224 - val_loss: 0.0193
# Epoch 26/100
#  - 3s - loss: 0.0221 - val_loss: 0.0196
# Epoch 27/100
#  - 2s - loss: 0.0220 - val_loss: 0.0205
# Epoch 28/100
#  - 3s - loss: 0.0219 - val_loss: 0.0220
# Epoch 29/100
#  - 2s - loss: 0.0219 - val_loss: 0.0220
# Epoch 30/100
#  - 3s - loss: 0.0218 - val_loss: 0.0218
# Epoch 31/100
#  - 3s - loss: 0.0217 - val_loss: 0.0217
# Epoch 32/100
#  - 3s - loss: 0.0218 - val_loss: 0.0203
# Epoch 33/100
#  - 3s - loss: 0.0216 - val_loss: 0.0209
# Epoch 34/100
#  - 3s - loss: 0.0217 - val_loss: 0.0197
# Epoch 35/100
#  - 3s - loss: 0.0213 - val_loss: 0.0197
# Epoch 36/100
#  - 3s - loss: 0.0213 - val_loss: 0.0192
# Epoch 37/100
#  - 2s - loss: 0.0212 - val_loss: 0.0191
# Epoch 38/100
#  - 2s - loss: 0.0211 - val_loss: 0.0188
# Epoch 39/100
#  - 3s - loss: 0.0209 - val_loss: 0.0185
# Epoch 40/100
#  - 3s - loss: 0.0208 - val_loss: 0.0184
# Epoch 41/100
#  - 3s - loss: 0.0207 - val_loss: 0.0185
# Epoch 42/100
#  - 3s - loss: 0.0206 - val_loss: 0.0186
# Epoch 43/100
#  - 2s - loss: 0.0205 - val_loss: 0.0183
# Epoch 44/100
#  - 2s - loss: 0.0204 - val_loss: 0.0185
# Epoch 45/100
#  - 2s - loss: 0.0203 - val_loss: 0.0184
# Epoch 46/100
#  - 2s - loss: 0.0202 - val_loss: 0.0181
# Epoch 47/100
#  - 3s - loss: 0.0200 - val_loss: 0.0182
# Epoch 48/100
#  - 2s - loss: 0.0200 - val_loss: 0.0181
# Epoch 49/100
#  - 3s - loss: 0.0198 - val_loss: 0.0179
# Epoch 50/100
#  - 3s - loss: 0.0196 - val_loss: 0.0172
# Epoch 51/100
#  - 3s - loss: 0.0196 - val_loss: 0.0170
# Epoch 52/100
#  - 3s - loss: 0.0194 - val_loss: 0.0169
# Epoch 53/100
#  - 3s - loss: 0.0193 - val_loss: 0.0164
# Epoch 54/100
#  - 3s - loss: 0.0191 - val_loss: 0.0160
# Epoch 55/100
#  - 3s - loss: 0.0189 - val_loss: 0.0161
# Epoch 56/100
#  - 2s - loss: 0.0187 - val_loss: 0.0155
# Epoch 57/100
#  - 3s - loss: 0.0185 - val_loss: 0.0156
# Epoch 58/100
#  - 3s - loss: 0.0184 - val_loss: 0.0154
# Epoch 59/100
#  - 2s - loss: 0.0181 - val_loss: 0.0154
# Epoch 60/100
#  - 3s - loss: 0.0179 - val_loss: 0.0166
# Epoch 61/100
#  - 3s - loss: 0.0179 - val_loss: 0.0154
# Epoch 62/100
#  - 3s - loss: 0.0176 - val_loss: 0.0156
# Epoch 63/100
#  - 3s - loss: 0.0175 - val_loss: 0.0153
# Epoch 64/100
#  - 2s - loss: 0.0174 - val_loss: 0.0155
# Epoch 65/100
#  - 3s - loss: 0.0172 - val_loss: 0.0153
# Epoch 66/100
#  - 3s - loss: 0.0171 - val_loss: 0.0154
# Epoch 67/100
#  - 3s - loss: 0.0170 - val_loss: 0.0152
# Epoch 68/100
#  - 3s - loss: 0.0169 - val_loss: 0.0154
# Epoch 69/100
#  - 3s - loss: 0.0168 - val_loss: 0.0153
# Epoch 70/100
#  - 3s - loss: 0.0167 - val_loss: 0.0154
# Epoch 71/100
#  - 3s - loss: 0.0166 - val_loss: 0.0153
# Epoch 72/100
#  - 3s - loss: 0.0165 - val_loss: 0.0153
# Epoch 73/100
#  - 3s - loss: 0.0164 - val_loss: 0.0152
# Epoch 74/100
#  - 2s - loss: 0.0164 - val_loss: 0.0153
# Epoch 75/100
#  - 2s - loss: 0.0163 - val_loss: 0.0153
# Epoch 76/100
#  - 3s - loss: 0.0161 - val_loss: 0.0152
# Epoch 77/100
#  - 3s - loss: 0.0161 - val_loss: 0.0151
# Epoch 78/100
#  - 2s - loss: 0.0161 - val_loss: 0.0151
# Epoch 79/100
#  - 3s - loss: 0.0159 - val_loss: 0.0151
# Epoch 80/100
#  - 3s - loss: 0.0159 - val_loss: 0.0151
# Epoch 81/100
#  - 3s - loss: 0.0159 - val_loss: 0.0151
# Epoch 82/100
#  - 3s - loss: 0.0158 - val_loss: 0.0149
# Epoch 83/100
#  - 3s - loss: 0.0158 - val_loss: 0.0151
# Epoch 84/100
#  - 3s - loss: 0.0157 - val_loss: 0.0148
# Epoch 85/100
#  - 3s - loss: 0.0156 - val_loss: 0.0150
# Epoch 86/100
#  - 3s - loss: 0.0155 - val_loss: 0.0150
# Epoch 87/100
#  - 3s - loss: 0.0155 - val_loss: 0.0149
# Epoch 88/100
#  - 3s - loss: 0.0155 - val_loss: 0.0152
# Epoch 89/100
#  - 3s - loss: 0.0154 - val_loss: 0.0150
# Epoch 90/100
#  - 3s - loss: 0.0153 - val_loss: 0.0149
# Epoch 91/100
#  - 3s - loss: 0.0153 - val_loss: 0.0150
# Epoch 92/100
#  - 3s - loss: 0.0152 - val_loss: 0.0150
# Epoch 93/100
#  - 3s - loss: 0.0152 - val_loss: 0.0152
# Epoch 94/100
#  - 3s - loss: 0.0151 - val_loss: 0.0150
# Epoch 95/100
#  - 3s - loss: 0.0151 - val_loss: 0.0150
# Epoch 96/100
#  - 3s - loss: 0.0149 - val_loss: 0.0153
# Epoch 97/100
#  - 3s - loss: 0.0149 - val_loss: 0.0151
# Epoch 98/100
#  - 3s - loss: 0.0149 - val_loss: 0.0150
# Epoch 99/100
#  - 3s - loss: 0.0148 - val_loss: 0.0153
# Epoch 100/100
#  - 3s - loss: 0.0148 - val_loss: 0.0152

# %%
history_loss = pd.DataFrame()
history_loss['train'] = history.history['loss']
history_loss['test'] = history.history['val_loss']
history_loss.plot(figsize=(10,10), fontsize=16,
                title='LSTM Model Loss');

# %%
# make a prediction 
yhat = model.predict(test_X)
# reshape back to 2d
test_X = test_X.reshape((test_X.shape[0], -1))

# invert scaling for forecast
inv_yhat = np.concatenate((test[:, 55:59], yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]

# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test[:, 55:59], test_y), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]
inv_yhat_gte_zero = inv_yhat.copy()
inv_yhat_gte_zero[inv_yhat_gte_zero < 0] = 0

# calculate r2
print("R2:  ", r2_score(inv_y, inv_yhat))

# calculate mean absolute error
print("MAE: ", mean_absolute_error(inv_y, inv_yhat))

# calculate rmse
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))
print("RMSE:", rmse)

# calculate mean absolute error percentage
maep = np.mean(np.abs((inv_y - inv_yhat)/inv_y))*100
print("mean absolute error percentage: ", maep)
# Out:
# R2:   0.9688437209959169
# MAE:  853.97906
# RMSE: 1161.252771794324
# mean absolute error percentage:  8.938854932785034

# %%
#train error(bias)
yhat_t = model.predict(train_X)
# reshape back to 2d
train_X = train_X.reshape((train_X.shape[0], -1))

# invert scaling for forecast
inv_yhat_t = np.concatenate((train[:, 55:59], yhat_t), axis=1)
inv_yhat_t = scaler.inverse_transform(inv_yhat_t)
inv_yhat_t = inv_yhat_t[:,-1]

# invert scaling for actual
train_y = train_y.reshape((len(train_y), 1))
inv_y_t = np.concatenate((train[:, 55:59], train_y), axis=1)
inv_y_t = scaler.inverse_transform(inv_y_t)
inv_y_t = inv_y_t[:,-1]
inv_yhat_gte_zero = inv_yhat_t.copy()
inv_yhat_gte_zero[inv_yhat_gte_zero < 0] = 0

# exlcude significantly deviated data
index = (np.abs((inv_y_t - inv_yhat_t)/inv_y_t) < 1)

# calculate r2
print("R2:  ", r2_score(inv_y_t[index], inv_yhat_t[index]))

# calculate mean absolute error
print("MAE: ", mean_absolute_error(inv_y_t[index], inv_yhat_t[index]))

# calculate rmse
rmse = math.sqrt(mean_squared_error(inv_y_t[index], inv_yhat_t[index]))
print("RMSE:", rmse)

# calculate mean absolute error percentage
maep = np.mean(np.abs((inv_y_t[index] - inv_yhat_t[index])/inv_y_t[index]))*100
print("mean absolute error percentage: ", maep)
# Out:
# R2:   0.9723108319140624
# MAE:  1032.7124
# RMSE: 1414.1977407703635
# mean absolute error percentage:  7.09647536277771

# %% [markdown]
# Time sequence 48hours(from 47 hours get 1 hours)

# %%
#normalize data & make LSTM model structure
features_and_target = pd.concat([data, num_pickups], axis = 1)
values = features_and_target.values

values = values.astype('float32')

scaler = MinMaxScaler(feature_range = (0, 1))
scaled = scaler.fit_transform(values)

n_hours = 47

reframed = series_to_supervised(scaled, n_hours, 1)

n_features = features_and_target.shape[1]

# %%
# exlcude significantly deviated data
total_values = reframed.values
n_p = np.argmin(total_values[365*24*3:, -1])
n_p = n_p + 365*24*3

a = total_values[: n_p, :]
b = total_values[n_p + n_hours + 1 : , :]
values = np.concatenate((a, b), axis=0)

# %%
# split into train and test sets  
n_train_hours = 365 * 24 * 3
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
n_obs = n_hours * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (26280, 235) 26280 (26280,)
# (26280, 47, 5) (26280,) (6469, 47, 5) (6469,)

# %%
# design network
model = Sequential()
model.add(LSTM(24, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

# fit network
history = model.fit(train_X, train_y, epochs=100, batch_size=100,
                    validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Train on 26280 samples, validate on 6469 samples
# Epoch 1/100
#  - 10s - loss: 0.1220 - val_loss: 0.0588
# Epoch 2/100
#  - 10s - loss: 0.0713 - val_loss: 0.0424
# Epoch 3/100
#  - 9s - loss: 0.0486 - val_loss: 0.0322
# Epoch 4/100
#  - 10s - loss: 0.0412 - val_loss: 0.0282
# Epoch 5/100
#  - 9s - loss: 0.0362 - val_loss: 0.0261
# Epoch 6/100
#  - 10s - loss: 0.0322 - val_loss: 0.0251
# Epoch 7/100
#  - 11s - loss: 0.0287 - val_loss: 0.0229
# Epoch 8/100
#  - 11s - loss: 0.0259 - val_loss: 0.0211
# Epoch 9/100
#  - 11s - loss: 0.0238 - val_loss: 0.0183
# Epoch 10/100
#  - 10s - loss: 0.0229 - val_loss: 0.0193
# Epoch 11/100
#  - 10s - loss: 0.0222 - val_loss: 0.0177
# Epoch 12/100
#  - 10s - loss: 0.0219 - val_loss: 0.0180
# Epoch 13/100
#  - 10s - loss: 0.0215 - val_loss: 0.0178
# Epoch 14/100
#  - 10s - loss: 0.0212 - val_loss: 0.0175
# Epoch 15/100
#  - 10s - loss: 0.0210 - val_loss: 0.0172
# Epoch 16/100
#  - 11s - loss: 0.0208 - val_loss: 0.0168
# Epoch 17/100
#  - 10s - loss: 0.0206 - val_loss: 0.0172
# Epoch 18/100
#  - 10s - loss: 0.0206 - val_loss: 0.0167
# Epoch 19/100
#  - 10s - loss: 0.0203 - val_loss: 0.0168
# Epoch 20/100
#  - 10s - loss: 0.0202 - val_loss: 0.0165
# Epoch 21/100
#  - 10s - loss: 0.0200 - val_loss: 0.0165
# Epoch 22/100
#  - 10s - loss: 0.0198 - val_loss: 0.0165
# Epoch 23/100
#  - 9s - loss: 0.0196 - val_loss: 0.0173
# Epoch 24/100
#  - 9s - loss: 0.0192 - val_loss: 0.0172
# Epoch 25/100
#  - 10s - loss: 0.0189 - val_loss: 0.0167
# Epoch 26/100
#  - 9s - loss: 0.0185 - val_loss: 0.0177
# Epoch 27/100
#  - 10s - loss: 0.0181 - val_loss: 0.0168
# Epoch 28/100
#  - 10s - loss: 0.0179 - val_loss: 0.0164
# Epoch 29/100
#  - 9s - loss: 0.0177 - val_loss: 0.0157
# Epoch 30/100
#  - 9s - loss: 0.0178 - val_loss: 0.0156
# Epoch 31/100
#  - 9s - loss: 0.0175 - val_loss: 0.0158
# Epoch 32/100
#  - 10s - loss: 0.0173 - val_loss: 0.0153
# Epoch 33/100
#  - 10s - loss: 0.0172 - val_loss: 0.0157
# Epoch 34/100
#  - 10s - loss: 0.0170 - val_loss: 0.0153
# Epoch 35/100
#  - 10s - loss: 0.0167 - val_loss: 0.0156
# Epoch 36/100
#  - 9s - loss: 0.0166 - val_loss: 0.0160
# Epoch 37/100
#  - 10s - loss: 0.0164 - val_loss: 0.0158
# Epoch 38/100
#  - 10s - loss: 0.0162 - val_loss: 0.0160
# Epoch 39/100
#  - 10s - loss: 0.0161 - val_loss: 0.0158
# Epoch 40/100
#  - 9s - loss: 0.0159 - val_loss: 0.0162
# Epoch 41/100
#  - 10s - loss: 0.0157 - val_loss: 0.0158
# Epoch 42/100
#  - 10s - loss: 0.0156 - val_loss: 0.0162
# Epoch 43/100
#  - 10s - loss: 0.0155 - val_loss: 0.0160
# Epoch 44/100
#  - 10s - loss: 0.0154 - val_loss: 0.0159
# Epoch 45/100
#  - 10s - loss: 0.0152 - val_loss: 0.0154
# Epoch 46/100
#  - 10s - loss: 0.0151 - val_loss: 0.0158
# Epoch 47/100
#  - 10s - loss: 0.0149 - val_loss: 0.0157
# Epoch 48/100
#  - 10s - loss: 0.0149 - val_loss: 0.0156
# Epoch 49/100
#  - 10s - loss: 0.0147 - val_loss: 0.0155
# Epoch 50/100
#  - 10s - loss: 0.0146 - val_loss: 0.0155
# Epoch 51/100
#  - 10s - loss: 0.0146 - val_loss: 0.0156
# Epoch 52/100
#  - 9s - loss: 0.0144 - val_loss: 0.0154
# Epoch 53/100
#  - 10s - loss: 0.0144 - val_loss: 0.0157
# Epoch 54/100
#  - 10s - loss: 0.0143 - val_loss: 0.0151
# Epoch 55/100
#  - 10s - loss: 0.0143 - val_loss: 0.0150
# Epoch 56/100
#  - 10s - loss: 0.0142 - val_loss: 0.0151
# Epoch 57/100
#  - 10s - loss: 0.0141 - val_loss: 0.0149
# Epoch 58/100
#  - 9s - loss: 0.0140 - val_loss: 0.0149
# Epoch 59/100
#  - 10s - loss: 0.0139 - val_loss: 0.0148
# Epoch 60/100
#  - 10s - loss: 0.0138 - val_loss: 0.0147
# Epoch 61/100
#  - 10s - loss: 0.0138 - val_loss: 0.0147
# Epoch 62/100
#  - 10s - loss: 0.0137 - val_loss: 0.0146
# Epoch 63/100
#  - 10s - loss: 0.0137 - val_loss: 0.0145
# Epoch 64/100
#  - 9s - loss: 0.0136 - val_loss: 0.0140
# Epoch 65/100
#  - 10s - loss: 0.0135 - val_loss: 0.0144
# Epoch 66/100
#  - 10s - loss: 0.0135 - val_loss: 0.0142
# Epoch 67/100
#  - 10s - loss: 0.0135 - val_loss: 0.0145
# Epoch 68/100
#  - 10s - loss: 0.0134 - val_loss: 0.0145
# Epoch 69/100
#  - 10s - loss: 0.0133 - val_loss: 0.0142
# Epoch 70/100
#  - 9s - loss: 0.0133 - val_loss: 0.0141
# Epoch 71/100
#  - 9s - loss: 0.0133 - val_loss: 0.0140
# Epoch 72/100
#  - 10s - loss: 0.0131 - val_loss: 0.0140
# Epoch 73/100
#  - 9s - loss: 0.0132 - val_loss: 0.0139
# Epoch 74/100
#  - 9s - loss: 0.0130 - val_loss: 0.0140
# Epoch 75/100
#  - 10s - loss: 0.0130 - val_loss: 0.0142
# Epoch 76/100
#  - 13s - loss: 0.0129 - val_loss: 0.0143
# Epoch 77/100
#  - 10s - loss: 0.0129 - val_loss: 0.0140
# Epoch 78/100
#  - 10s - loss: 0.0128 - val_loss: 0.0140
# Epoch 79/100
#  - 10s - loss: 0.0129 - val_loss: 0.0138
# Epoch 80/100
#  - 10s - loss: 0.0128 - val_loss: 0.0138
# Epoch 81/100
#  - 10s - loss: 0.0127 - val_loss: 0.0140
# Epoch 82/100
#  - 10s - loss: 0.0127 - val_loss: 0.0137
# Epoch 83/100
#  - 10s - loss: 0.0126 - val_loss: 0.0142
# Epoch 84/100
#  - 10s - loss: 0.0126 - val_loss: 0.0138
# Epoch 85/100
#  - 10s - loss: 0.0126 - val_loss: 0.0136
# Epoch 86/100
#  - 10s - loss: 0.0125 - val_loss: 0.0137
# Epoch 87/100
#  - 10s - loss: 0.0125 - val_loss: 0.0136
# Epoch 88/100
#  - 10s - loss: 0.0125 - val_loss: 0.0139
# Epoch 89/100
#  - 9s - loss: 0.0124 - val_loss: 0.0136
# Epoch 90/100
#  - 10s - loss: 0.0124 - val_loss: 0.0136
# Epoch 91/100
#  - 9s - loss: 0.0124 - val_loss: 0.0138
# Epoch 92/100
#  - 13s - loss: 0.0124 - val_loss: 0.0136
# Epoch 93/100
#  - 9s - loss: 0.0124 - val_loss: 0.0135
# Epoch 94/100
#  - 10s - loss: 0.0124 - val_loss: 0.0140
# Epoch 95/100
#  - 10s - loss: 0.0124 - val_loss: 0.0138
# Epoch 96/100
#  - 10s - loss: 0.0123 - val_loss: 0.0141
# Epoch 97/100
#  - 10s - loss: 0.0123 - val_loss: 0.0134
# Epoch 98/100
#  - 9s - loss: 0.0123 - val_loss: 0.0134
# Epoch 99/100
#  - 12s - loss: 0.0122 - val_loss: 0.0135
# Epoch 100/100
#  - 12s - loss: 0.0123 - val_loss: 0.0135

# %%
history_loss = pd.DataFrame()
history_loss['train'] = history.history['loss']
history_loss['test'] = history.history['val_loss']
history_loss.plot(figsize=(10,10), fontsize=16,
                title='LSTM Model Loss');

# %%
# make a prediction 
yhat = model.predict(test_X)
# reshape back to 2d
test_X = test_X.reshape((test_X.shape[0], -1))

# invert scaling for forecast
inv_yhat = np.concatenate((test[:, 235:239], yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]

# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test[:, 235:239], test_y), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]
inv_yhat_gte_zero = inv_yhat.copy()
inv_yhat_gte_zero[inv_yhat_gte_zero < 0] = 0

# calculate r2
print("R2:  ", r2_score(inv_y, inv_yhat))

# calculate mean absolute error
print("MAE: ", mean_absolute_error(inv_y, inv_yhat))

# calculate rmse
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))
print("RMSE:", rmse)

# calculate mean absolute error percentage
maep = np.mean(np.abs((inv_y - inv_yhat)/inv_y))*100
print("mean absolute error percentage: ", maep)
# Out:
# R2:   0.9724040041461655
# MAE:  759.6086
# RMSE: 1093.089257563169
# mean absolute error percentage:  6.802564859390259

# %%
#train error(bias)
yhat_t = model.predict(train_X)
# reshape back to 2d
train_X = train_X.reshape((train_X.shape[0], -1))

# invert scaling for forecast
inv_yhat_t = np.concatenate((train[:, 235:239], yhat_t), axis=1)
inv_yhat_t = scaler.inverse_transform(inv_yhat_t)
inv_yhat_t = inv_yhat_t[:,-1]

# invert scaling for actual
train_y = train_y.reshape((len(train_y), 1))
inv_y_t = np.concatenate((train[:, 235:239], train_y), axis=1)
inv_y_t = scaler.inverse_transform(inv_y_t)
inv_y_t = inv_y_t[:,-1]
inv_yhat_gte_zero = inv_yhat_t.copy()
inv_yhat_gte_zero[inv_yhat_gte_zero < 0] = 0

# exlcude significantly deviated data
index = (np.abs((inv_y_t - inv_yhat_t)/inv_y_t) < 1)

# calculate r2
print("R2:  ", r2_score(inv_y_t[index], inv_yhat_t[index]))

# calculate mean absolute error
print("MAE: ", mean_absolute_error(inv_y_t[index], inv_yhat_t[index]))

# calculate rmse
rmse = math.sqrt(mean_squared_error(inv_y_t[index], inv_yhat_t[index]))
print("RMSE:", rmse)

# calculate mean absolute error percentage
maep = np.mean(np.abs((inv_y_t[index] - inv_yhat_t[index])/inv_y_t[index]))*100
print("mean absolute error percentage: ", maep)
# Out:
# R2:   0.9750566050202504
# MAE:  939.903
# RMSE: 1342.5112196924092
# mean absolute error percentage:  6.257264316082001
