# %%
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, Normalizer
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %matplotlib inline
# plt.style.use("ggplot")
sns.set_style("darkgrid")
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
data = pd.read_csv("final_5minutes.csv")
data.drop(['Month'], axis =1, inplace= True)
#data.set_index("time", inplace= True)
num_pickups = data.total
num_green_pickups = data.green
num_yellow_pickups = data.yellow
data.drop(['Unnamed: 0',  'green', 'yellow', 'total'], axis =1, inplace = True)

# %%
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    
    agg = pd.concat(cols, axis = 1)
    agg.columns = names
    
    if dropnan:
        agg.dropna(inplace = True)
        
    return agg

# %%
#normalize data & make LSTM model structure
features_and_target = pd.concat([data, num_pickups], axis = 1)
values = features_and_target.values

values = values.astype('float32')

scaler = MinMaxScaler(feature_range = (0, 1))
scaled = scaler.fit_transform(values)

n_hours = 47

reframed = series_to_supervised(scaled, n_hours, 1)

n_features = features_and_target.shape[1]

# %%
# exlcude significantly deviated data
total_values = reframed.values
n_p = np.argmin(total_values[365*24*3*12:, -1])
n_p = n_p + 365*24*3*12

a = total_values[: n_p, :]
b = total_values[n_p + n_hours + 12 + 1 : , :]
values = np.concatenate((a, b), axis=0)

# %%
# split into train and test sets 
n_train_hours = 365 * 24 * 3 * 12
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
n_obs = n_hours * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (315360, 235) 315360 (315360,)
# (315360, 47, 5) (315360,) (78805, 47, 5) (78805,)

# %%
# design network
model = Sequential()
model.add(LSTM(24, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

# fit network
history = model.fit(train_X, train_y, epochs=100, batch_size=100,
                    validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Train on 315360 samples, validate on 78805 samples
# Epoch 1/100
#  - 85s - loss: 0.0215 - val_loss: 0.0126
# Epoch 2/100
#  - 83s - loss: 0.0119 - val_loss: 0.0095
# Epoch 3/100
#  - 83s - loss: 0.0113 - val_loss: 0.0104
# Epoch 4/100
#  - 85s - loss: 0.0109 - val_loss: 0.0118
# Epoch 5/100
#  - 94s - loss: 0.0109 - val_loss: 0.0107
# Epoch 6/100
#  - 81s - loss: 0.0106 - val_loss: 0.0104
# Epoch 7/100
#  - 77s - loss: 0.0105 - val_loss: 0.0101
# Epoch 8/100
#  - 77s - loss: 0.0105 - val_loss: 0.0089
# Epoch 9/100
#  - 76s - loss: 0.0107 - val_loss: 0.0094
# Epoch 10/100
#  - 77s - loss: 0.0102 - val_loss: 0.0092
# Epoch 11/100
#  - 76s - loss: 0.0105 - val_loss: 0.0092
# Epoch 12/100
#  - 76s - loss: 0.0103 - val_loss: 0.0091
# Epoch 13/100
#  - 77s - loss: 0.0102 - val_loss: 0.0086
# Epoch 14/100
#  - 77s - loss: 0.0101 - val_loss: 0.0086
# Epoch 15/100
#  - 77s - loss: 0.0101 - val_loss: 0.0087
# Epoch 16/100
#  - 77s - loss: 0.0099 - val_loss: 0.0093
# Epoch 17/100
#  - 79s - loss: 0.0098 - val_loss: 0.0093
# Epoch 18/100
#  - 78s - loss: 0.0098 - val_loss: 0.0086
# Epoch 19/100
#  - 78s - loss: 0.0096 - val_loss: 0.0083
# Epoch 20/100
#  - 80s - loss: 0.0096 - val_loss: 0.0085
# Epoch 21/100
#  - 79s - loss: 0.0096 - val_loss: 0.0091
# Epoch 22/100
#  - 79s - loss: 0.0092 - val_loss: 0.0084
# Epoch 23/100
#  - 77s - loss: 0.0094 - val_loss: 0.0084
# Epoch 24/100
#  - 78s - loss: 0.0092 - val_loss: 0.0093
# Epoch 25/100
#  - 82s - loss: 0.0091 - val_loss: 0.0089
# Epoch 26/100
#  - 83s - loss: 0.0091 - val_loss: 0.0087
# Epoch 27/100
#  - 81s - loss: 0.0091 - val_loss: 0.0084
# Epoch 28/100
#  - 83s - loss: 0.0092 - val_loss: 0.0085
# Epoch 29/100
#  - 84s - loss: 0.0090 - val_loss: 0.0093
# Epoch 30/100
#  - 83s - loss: 0.0091 - val_loss: 0.0085
# Epoch 31/100
#  - 82s - loss: 0.0091 - val_loss: 0.0085
# Epoch 32/100
#  - 83s - loss: 0.0090 - val_loss: 0.0085
# Epoch 33/100
#  - 83s - loss: 0.0090 - val_loss: 0.0087
# Epoch 34/100
#  - 83s - loss: 0.0090 - val_loss: 0.0084
# Epoch 35/100
#  - 83s - loss: 0.0090 - val_loss: 0.0091
# Epoch 36/100
#  - 83s - loss: 0.0090 - val_loss: 0.0084
# Epoch 37/100
#  - 83s - loss: 0.0089 - val_loss: 0.0086
# Epoch 38/100
#  - 83s - loss: 0.0090 - val_loss: 0.0085
# Epoch 39/100
#  - 83s - loss: 0.0089 - val_loss: 0.0087
# Epoch 40/100
#  - 82s - loss: 0.0089 - val_loss: 0.0086
# Epoch 41/100
#  - 82s - loss: 0.0089 - val_loss: 0.0083
# Epoch 42/100
#  - 83s - loss: 0.0089 - val_loss: 0.0084
# Epoch 43/100
#  - 82s - loss: 0.0089 - val_loss: 0.0090
# Epoch 44/100
#  - 83s - loss: 0.0089 - val_loss: 0.0091
# Epoch 45/100
#  - 82s - loss: 0.0089 - val_loss: 0.0090
# Epoch 46/100
#  - 83s - loss: 0.0089 - val_loss: 0.0095
# Epoch 47/100
#  - 83s - loss: 0.0089 - val_loss: 0.0092
# Epoch 48/100
#  - 83s - loss: 0.0088 - val_loss: 0.0092
# Epoch 49/100
#  - 83s - loss: 0.0089 - val_loss: 0.0084
# Epoch 50/100
#  - 83s - loss: 0.0088 - val_loss: 0.0088
# Epoch 51/100
#  - 83s - loss: 0.0088 - val_loss: 0.0095
# Epoch 52/100
#  - 83s - loss: 0.0088 - val_loss: 0.0086
# Epoch 53/100
#  - 83s - loss: 0.0088 - val_loss: 0.0086
# Epoch 54/100
#  - 86s - loss: 0.0088 - val_loss: 0.0087
# Epoch 55/100
#  - 84s - loss: 0.0088 - val_loss: 0.0089
# Epoch 56/100
#  - 82s - loss: 0.0088 - val_loss: 0.0087
# Epoch 57/100
#  - 84s - loss: 0.0088 - val_loss: 0.0091
# Epoch 58/100
#  - 83s - loss: 0.0087 - val_loss: 0.0088
# Epoch 59/100
#  - 84s - loss: 0.0088 - val_loss: 0.0088
# Epoch 60/100
#  - 82s - loss: 0.0087 - val_loss: 0.0090
# Epoch 61/100
#  - 84s - loss: 0.0087 - val_loss: 0.0087
# Epoch 62/100
#  - 83s - loss: 0.0087 - val_loss: 0.0089
# Epoch 63/100
#  - 84s - loss: 0.0088 - val_loss: 0.0091
# Epoch 64/100
#  - 82s - loss: 0.0087 - val_loss: 0.0088
# Epoch 65/100
#  - 84s - loss: 0.0087 - val_loss: 0.0090
# Epoch 66/100
#  - 82s - loss: 0.0087 - val_loss: 0.0085
# Epoch 67/100
#  - 83s - loss: 0.0087 - val_loss: 0.0089
# Epoch 68/100
#  - 84s - loss: 0.0087 - val_loss: 0.0091
# Epoch 69/100
#  - 83s - loss: 0.0087 - val_loss: 0.0086
# Epoch 70/100
#  - 84s - loss: 0.0087 - val_loss: 0.0088
# Epoch 71/100
#  - 83s - loss: 0.0087 - val_loss: 0.0089
# Epoch 72/100
#  - 84s - loss: 0.0086 - val_loss: 0.0086
# Epoch 73/100
#  - 83s - loss: 0.0087 - val_loss: 0.0086
# Epoch 74/100
#  - 83s - loss: 0.0086 - val_loss: 0.0088
# Epoch 75/100
#  - 83s - loss: 0.0087 - val_loss: 0.0088
# Epoch 76/100
#  - 83s - loss: 0.0086 - val_loss: 0.0086
# Epoch 77/100
#  - 83s - loss: 0.0086 - val_loss: 0.0088
# Epoch 78/100
#  - 83s - loss: 0.0087 - val_loss: 0.0086
# Epoch 79/100
#  - 82s - loss: 0.0086 - val_loss: 0.0088
# Epoch 80/100
#  - 83s - loss: 0.0087 - val_loss: 0.0087
# Epoch 81/100
#  - 84s - loss: 0.0086 - val_loss: 0.0085
# Epoch 82/100
#  - 83s - loss: 0.0086 - val_loss: 0.0086
# Epoch 83/100
#  - 84s - loss: 0.0086 - val_loss: 0.0086
# Epoch 84/100
#  - 83s - loss: 0.0086 - val_loss: 0.0088
# Epoch 85/100
#  - 84s - loss: 0.0086 - val_loss: 0.0085
# Epoch 86/100
#  - 82s - loss: 0.0086 - val_loss: 0.0087
# Epoch 87/100
#  - 84s - loss: 0.0086 - val_loss: 0.0083
# Epoch 88/100
#  - 82s - loss: 0.0085 - val_loss: 0.0086
# Epoch 89/100
#  - 83s - loss: 0.0086 - val_loss: 0.0086
# Epoch 90/100
#  - 83s - loss: 0.0086 - val_loss: 0.0086
# Epoch 91/100
#  - 84s - loss: 0.0086 - val_loss: 0.0086
# Epoch 92/100
#  - 82s - loss: 0.0086 - val_loss: 0.0083
# Epoch 93/100
#  - 83s - loss: 0.0086 - val_loss: 0.0085
# Epoch 94/100
#  - 83s - loss: 0.0086 - val_loss: 0.0086
# Epoch 95/100
#  - 82s - loss: 0.0086 - val_loss: 0.0082
# Epoch 96/100
#  - 83s - loss: 0.0085 - val_loss: 0.0085
# Epoch 97/100
#  - 82s - loss: 0.0086 - val_loss: 0.0085
# Epoch 98/100
#  - 83s - loss: 0.0086 - val_loss: 0.0082
# Epoch 99/100
#  - 82s - loss: 0.0085 - val_loss: 0.0083
# Epoch 100/100
#  - 83s - loss: 0.0085 - val_loss: 0.0085

# %%
history_loss = pd.DataFrame()
history_loss['train'] = history.history['loss']
history_loss['test'] = history.history['val_loss']
history_loss.plot(figsize=(10,10), fontsize=16,
                title='LSTM Model Loss');

# %%
# make a prediction 
yhat = model.predict(test_X)
# reshape back to 2d
test_X = test_X.reshape((test_X.shape[0], -1))

# invert scaling for forecast# invert 
inv_yhat = np.concatenate((test[:, 235:239], yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]

# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test[:, 235:239], test_y), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]
inv_yhat_gte_zero = inv_yhat.copy()
inv_yhat_gte_zero[inv_yhat_gte_zero < 0] = 0

# calculate r2
print("R2:  ", r2_score(inv_y, inv_yhat))

# calculate mean absolute error
print("MAE: ", mean_absolute_error(inv_y, inv_yhat))

# calculate rmse
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))
print("RMSE:", rmse)

# calculate mean absolute error percentage
maep = np.mean(np.abs((inv_y - inv_yhat)/inv_y))*100
print("mean absolute error percentage: ", maep)
# Out:
# R2:   0.9902862236073744
# MAE:  40.85596
# RMSE: 54.82362522501134
# mean absolute error percentage:  4.339626803994179

# %%
#train error(bias)
yhat_t = model.predict(train_X)
# reshape back to 2d
train_X = train_X.reshape((train_X.shape[0], -1))

# invert scaling for forecast
inv_yhat_t = np.concatenate((train[:, 235:239], yhat_t), axis=1)
inv_yhat_t = scaler.inverse_transform(inv_yhat_t)
inv_yhat_t = inv_yhat_t[:,-1]

# invert scaling for actual
train_y = train_y.reshape((len(train_y), 1))
inv_y_t = np.concatenate((train[:, 235:239], train_y), axis=1)
inv_y_t = scaler.inverse_transform(inv_y_t)
inv_y_t = inv_y_t[:,-1]
inv_yhat_gte_zero = inv_yhat_t.copy()
inv_yhat_gte_zero[inv_yhat_gte_zero < 0] = 0

# exlcude significantly deviated data
index = (np.abs((inv_y_t - inv_yhat_t)/inv_y_t) < 1)

# calculate r2
print("R2:  ", r2_score(inv_y_t[index], inv_yhat_t[index]))

# calculate mean absolute error
print("MAE: ", mean_absolute_error(inv_y_t[index], inv_yhat_t[index]))

# calculate rmse
rmse = math.sqrt(mean_squared_error(inv_y_t[index], inv_yhat_t[index]))
print("RMSE:", rmse)

# calculate mean absolute error percentage
maep = np.mean(np.abs((inv_y_t[index] - inv_yhat_t[index])/inv_y_t[index]))*100
print("mean absolute error percentage: ", maep)
# Out:
# R2:   0.9878952949488915
# MAE:  58.64063
# RMSE: 79.00149264313777
# mean absolute error percentage:  4.194515198469162
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: RuntimeWarning: divide by zero encountered in true_divide

# %% [markdown]
# Set for same data size

# %%
# split into train and test sets 
n_train_hours = 365 * 24 * 3 * 12
train = values[n_train_hours - 26280 :n_train_hours, :]
test = values[n_train_hours:n_train_hours + 6469, :]
# split into input and outputs
n_obs = n_hours * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (26280, 235) 26280 (26280,)
# (26280, 47, 5) (26280,) (6469, 47, 5) (6469,)

# %%
# design network
model = Sequential()
model.add(LSTM(24, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

# fit network
history = model.fit(train_X, train_y, epochs=100, batch_size=100,
                    validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Train on 26280 samples, validate on 6469 samples
# Epoch 1/100
#  - 10s - loss: 0.0544 - val_loss: 0.0277
# Epoch 2/100
#  - 9s - loss: 0.0249 - val_loss: 0.0215
# Epoch 3/100
#  - 9s - loss: 0.0190 - val_loss: 0.0181
# Epoch 4/100
#  - 9s - loss: 0.0161 - val_loss: 0.0165
# Epoch 5/100
#  - 9s - loss: 0.0171 - val_loss: 0.0215
# Epoch 6/100
#  - 10s - loss: 0.0151 - val_loss: 0.0138
# Epoch 7/100
#  - 9s - loss: 0.0148 - val_loss: 0.0136
# Epoch 8/100
#  - 7s - loss: 0.0138 - val_loss: 0.0130
# Epoch 9/100
#  - 7s - loss: 0.0137 - val_loss: 0.0127
# Epoch 10/100
#  - 7s - loss: 0.0135 - val_loss: 0.0126
# Epoch 11/100
#  - 7s - loss: 0.0131 - val_loss: 0.0120
# Epoch 12/100
#  - 7s - loss: 0.0130 - val_loss: 0.0132
# Epoch 13/100
#  - 7s - loss: 0.0123 - val_loss: 0.0113
# Epoch 14/100
#  - 7s - loss: 0.0121 - val_loss: 0.0111
# Epoch 15/100
#  - 7s - loss: 0.0120 - val_loss: 0.0112
# Epoch 16/100
#  - 7s - loss: 0.0119 - val_loss: 0.0114
# Epoch 17/100
#  - 7s - loss: 0.0116 - val_loss: 0.0110
# Epoch 18/100
#  - 7s - loss: 0.0116 - val_loss: 0.0111
# Epoch 19/100
#  - 7s - loss: 0.0115 - val_loss: 0.0113
# Epoch 20/100
#  - 7s - loss: 0.0114 - val_loss: 0.0113
# Epoch 21/100
#  - 7s - loss: 0.0113 - val_loss: 0.0108
# Epoch 22/100
#  - 7s - loss: 0.0111 - val_loss: 0.0104
# Epoch 23/100
#  - 7s - loss: 0.0112 - val_loss: 0.0116
# Epoch 24/100
#  - 7s - loss: 0.0107 - val_loss: 0.0105
# Epoch 25/100
#  - 7s - loss: 0.0111 - val_loss: 0.0114
# Epoch 26/100
#  - 7s - loss: 0.0105 - val_loss: 0.0101
# Epoch 27/100
#  - 7s - loss: 0.0110 - val_loss: 0.0114
# Epoch 28/100
#  - 7s - loss: 0.0103 - val_loss: 0.0099
# Epoch 29/100
#  - 7s - loss: 0.0110 - val_loss: 0.0114
# Epoch 30/100
#  - 7s - loss: 0.0103 - val_loss: 0.0105
# Epoch 31/100
#  - 7s - loss: 0.0108 - val_loss: 0.0110
# Epoch 32/100
#  - 7s - loss: 0.0102 - val_loss: 0.0105
# Epoch 33/100
#  - 7s - loss: 0.0105 - val_loss: 0.0110
# Epoch 34/100
#  - 7s - loss: 0.0104 - val_loss: 0.0116
# Epoch 35/100
#  - 7s - loss: 0.0101 - val_loss: 0.0106
# Epoch 36/100
#  - 7s - loss: 0.0105 - val_loss: 0.0107
# Epoch 37/100
#  - 7s - loss: 0.0102 - val_loss: 0.0115
# Epoch 38/100
#  - 7s - loss: 0.0101 - val_loss: 0.0111
# Epoch 39/100
#  - 7s - loss: 0.0102 - val_loss: 0.0112
# Epoch 40/100
#  - 7s - loss: 0.0101 - val_loss: 0.0108
# Epoch 41/100
#  - 7s - loss: 0.0101 - val_loss: 0.0115
# Epoch 42/100
#  - 7s - loss: 0.0100 - val_loss: 0.0111
# Epoch 43/100
#  - 7s - loss: 0.0101 - val_loss: 0.0113
# Epoch 44/100
#  - 7s - loss: 0.0100 - val_loss: 0.0115
# Epoch 45/100
#  - 7s - loss: 0.0100 - val_loss: 0.0112
# Epoch 46/100
#  - 7s - loss: 0.0100 - val_loss: 0.0119
# Epoch 47/100
#  - 7s - loss: 0.0103 - val_loss: 0.0120
# Epoch 48/100
#  - 7s - loss: 0.0095 - val_loss: 0.0091
# Epoch 49/100
#  - 7s - loss: 0.0103 - val_loss: 0.0120
# Epoch 50/100
#  - 7s - loss: 0.0103 - val_loss: 0.0108
# Epoch 51/100
#  - 7s - loss: 0.0108 - val_loss: 0.0120
# Epoch 52/100
#  - 7s - loss: 0.0098 - val_loss: 0.0090
# Epoch 53/100
#  - 7s - loss: 0.0101 - val_loss: 0.0117
# Epoch 54/100
#  - 7s - loss: 0.0096 - val_loss: 0.0105
# Epoch 55/100
#  - 7s - loss: 0.0101 - val_loss: 0.0123
# Epoch 56/100
#  - 7s - loss: 0.0097 - val_loss: 0.0111
# Epoch 57/100
#  - 7s - loss: 0.0096 - val_loss: 0.0117
# Epoch 58/100
#  - 7s - loss: 0.0103 - val_loss: 0.0120
# Epoch 59/100
#  - 7s - loss: 0.0096 - val_loss: 0.0109
# Epoch 60/100
#  - 7s - loss: 0.0094 - val_loss: 0.0107
# Epoch 61/100
#  - 7s - loss: 0.0099 - val_loss: 0.0117
# Epoch 62/100
#  - 7s - loss: 0.0098 - val_loss: 0.0111
# Epoch 63/100
#  - 7s - loss: 0.0095 - val_loss: 0.0110
# Epoch 64/100
#  - 7s - loss: 0.0101 - val_loss: 0.0120
# Epoch 65/100
#  - 7s - loss: 0.0094 - val_loss: 0.0108
# Epoch 66/100
#  - 7s - loss: 0.0100 - val_loss: 0.0095
# Epoch 67/100
#  - 7s - loss: 0.0105 - val_loss: 0.0121
# Epoch 68/100
#  - 7s - loss: 0.0098 - val_loss: 0.0091
# Epoch 69/100
#  - 7s - loss: 0.0095 - val_loss: 0.0118
# Epoch 70/100
#  - 7s - loss: 0.0100 - val_loss: 0.0097
# Epoch 71/100
#  - 7s - loss: 0.0101 - val_loss: 0.0110
# Epoch 72/100
#  - 7s - loss: 0.0106 - val_loss: 0.0118
# Epoch 73/100
#  - 7s - loss: 0.0096 - val_loss: 0.0096
# Epoch 74/100
#  - 7s - loss: 0.0097 - val_loss: 0.0105
# Epoch 75/100
#  - 7s - loss: 0.0102 - val_loss: 0.0112
# Epoch 76/100
#  - 7s - loss: 0.0096 - val_loss: 0.0088
# Epoch 77/100
#  - 7s - loss: 0.0106 - val_loss: 0.0101
# Epoch 78/100
#  - 7s - loss: 0.0097 - val_loss: 0.0127
# Epoch 79/100
#  - 7s - loss: 0.0100 - val_loss: 0.0097
# Epoch 80/100
#  - 7s - loss: 0.0097 - val_loss: 0.0092
# Epoch 81/100
#  - 7s - loss: 0.0104 - val_loss: 0.0098
# Epoch 82/100
#  - 7s - loss: 0.0091 - val_loss: 0.0100
# Epoch 83/100
#  - 7s - loss: 0.0093 - val_loss: 0.0088
# Epoch 84/100
#  - 7s - loss: 0.0099 - val_loss: 0.0114
# Epoch 85/100
#  - 7s - loss: 0.0095 - val_loss: 0.0094
# Epoch 86/100
#  - 7s - loss: 0.0098 - val_loss: 0.0108
# Epoch 87/100
#  - 7s - loss: 0.0109 - val_loss: 0.0103
# Epoch 88/100
#  - 7s - loss: 0.0095 - val_loss: 0.0098
# Epoch 89/100
#  - 7s - loss: 0.0095 - val_loss: 0.0111
# Epoch 90/100
#  - 7s - loss: 0.0095 - val_loss: 0.0093
# Epoch 91/100
#  - 7s - loss: 0.0096 - val_loss: 0.0099
# Epoch 92/100
#  - 7s - loss: 0.0108 - val_loss: 0.0093
# Epoch 93/100
#  - 7s - loss: 0.0095 - val_loss: 0.0098
# Epoch 94/100
#  - 7s - loss: 0.0109 - val_loss: 0.0093
# Epoch 95/100
#  - 7s - loss: 0.0103 - val_loss: 0.0099
# Epoch 96/100
#  - 7s - loss: 0.0104 - val_loss: 0.0093
# Epoch 97/100
#  - 7s - loss: 0.0100 - val_loss: 0.0094
# Epoch 98/100
#  - 7s - loss: 0.0101 - val_loss: 0.0095
# Epoch 99/100
#  - 7s - loss: 0.0100 - val_loss: 0.0094
# Epoch 100/100
#  - 7s - loss: 0.0099 - val_loss: 0.0095

# %%
# make a prediction 
yhat = model.predict(test_X)
# reshape back to 2d
test_X = test_X.reshape((test_X.shape[0], -1))

# invert scaling for forecast# invert 
inv_yhat = np.concatenate((test[:, 235:239], yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]

# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test[:, 235:239], test_y), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]
inv_yhat_gte_zero = inv_yhat.copy()
inv_yhat_gte_zero[inv_yhat_gte_zero < 0] = 0

# calculate r2
print("R2:  ", r2_score(inv_y, inv_yhat))

# calculate mean absolute error
print("MAE: ", mean_absolute_error(inv_y, inv_yhat))

# calculate rmse
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))
print("RMSE:", rmse)

# calculate mean absolute error percentage
maep = np.mean(np.abs((inv_y - inv_yhat)/inv_y))*100
print("mean absolute error percentage: ", maep)
# Out:
# R2:   0.9880702542809908
# MAE:  45.968204
# RMSE: 60.793563983986004
# mean absolute error percentage:  5.405549332499504

# %%
#train error(bias)
yhat_t = model.predict(train_X)
# reshape back to 2d
train_X = train_X.reshape((train_X.shape[0], -1))

# invert scaling for forecast
inv_yhat_t = np.concatenate((train[:, 235:239], yhat_t), axis=1)
inv_yhat_t = scaler.inverse_transform(inv_yhat_t)
inv_yhat_t = inv_yhat_t[:,-1]

# invert scaling for actual
train_y = train_y.reshape((len(train_y), 1))
inv_y_t = np.concatenate((train[:, 235:239], train_y), axis=1)
inv_y_t = scaler.inverse_transform(inv_y_t)
inv_y_t = inv_y_t[:,-1]
inv_yhat_gte_zero = inv_yhat_t.copy()
inv_yhat_gte_zero[inv_yhat_gte_zero < 0] = 0

# exlcude significantly deviated data
index = (np.abs((inv_y_t - inv_yhat_t)/inv_y_t) < 1)

# calculate r2
print("R2:  ", r2_score(inv_y_t[index], inv_yhat_t[index]))

# calculate mean absolute error
print("MAE: ", mean_absolute_error(inv_y_t[index], inv_yhat_t[index]))

# calculate rmse
rmse = math.sqrt(mean_squared_error(inv_y_t[index], inv_yhat_t[index]))
print("RMSE:", rmse)

# calculate mean absolute error percentage
maep = np.mean(np.abs((inv_y_t[index] - inv_yhat_t[index])/inv_y_t[index]))*100
print("mean absolute error percentage: ", maep)
# Out:
# R2:   0.9893196165488852
# MAE:  46.780636
# RMSE: 61.7921339837493
# mean absolute error percentage:  4.7499921172857285
